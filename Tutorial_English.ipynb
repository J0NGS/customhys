# %% [markdown]
# # Automated Metaheuristic Design with CustomHyS
# > CUSTOMHyS: Customising Optimisation Metaheuristics via
# Hyper-heuristic Search
# Por: Jorge Mario Cruz Duarte [(jorge.cruz@tec.mx)](mailto:jorge.cruz@tec.mx)
#
# This tutorial is based on the manuscript at [SoftwareX](https://www.sciencedirect.com/science/article/pii/S2352711020303411)

# %% [markdown]
# ## 0. Installing the package or downloading it from GitHub
# This only applies if you don't have the package installed, for example, when using Google Colab.

# %%
# !pip install customhys==1.1.6.
# !pip install latex
# !pip install optproblems

# %%
# !git clone https://github.com/jcrvz/customhys.git .

# %% [markdown]
# ## 1. Module of Benchmark Functions (customhys.benchmark_func)
# In this section, we will see how to use the test functions that come with the framework.
#
# First, we will load the corresponding module and other utilities for plotting.

# %%
from cProfile import label

from customhys import benchmark_func as bf

import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

import numpy as np
import pandas as pd

# %% [markdown]
# Let us see the list of benchmark functions:

# %%
functions =bf.__all__
functions
# Out:
# ['Ackley1',
#  'Ackley4',
#  'Alpine1',
#  'Alpine2',
#  'Bohachevsky',
#  'Brent',
#  'Brown',
#  'CarromTable',
#  'ChungReynolds',
#  'Cigar',
#  'CosineMixture',
#  'CrossInTray',
#  'CrossLegTable',
#  'CrownedCross',
#  'Csendes',
#  'Deb1',
#  'Deb2',
#  'DeflectedCorrugatedSpring',
#  'DixonPrice',
#  'DropWave',
#  'EggHolder',
#  'Ellipsoid',
#  'ExpandedDecreasingMinima',
#  'ExpandedEqualMinima',
#  'ExpandedFiveUnevenPeakTrap',
#  'ExpandedTwoPeakTrap',
#  'ExpandedUnevenMinima',
#  'Exponential',
#  'F2',
#  'Giunta',
#  'Griewank',
#  'HappyCat',
#  'HyperEllipsoid',
#  'InvertedCosineWave',
#  'JennrichSampson',
#  'KTablet',
#  'Katsuura',
#  'Levy',
#  'LunacekN01',
#  'LunacekN02',
#  'Michalewicz',
#  'Mishra1',
#  'Mishra2',
#  'Mishra7',
#  'Mishra11',
#  'ModifiedVincent',
#  'NeedleEye',
#  'Pathological',
#  'Periodic',
#  'Perm01',
#  'Perm02',
#  'Pinter',
#  'PowellSum',
#  'Price01',
#  'Qing',
#  'Quartic',
#  'Quintic',
#  'Rana',
#  'Rastrigin',
#  'Ridge',
#  'Rosenbrock',
#  'RotatedHyperEllipsoid',
#  'Salomon',
#  'Sargan',
#  'SchafferN1',
#  'SchafferN2',
#  'SchafferN3',
#  'SchafferN4',
#  'SchafferN6',
#  'Schubert',
#  'Schubert3',
#  'Schubert4',
#  'SchumerSteiglitz',
#  'Schwefel',
#  'Schwefel12',
#  'Schwefel204',
#  'Schwefel220',
#  'Schwefel221',
#  'Schwefel222',
#  'Schwefel223',
#  'Schwefel225',
#  'Schwefel226',
#  'Sphere',
#  'Step',
#  'Step2',
#  'Step3',
#  'StepInt',
#  'Stochastic',
#  'StrechedVSineWave',
#  'StyblinskiTang',
#  'SumSquares',
#  'Trid',
#  'Trigonometric1',
#  'Trigonometric2',
#  'TypeI',
#  'TypeII',
#  'Vincent',
#  'WWavy',
#  'Weierstrass',
#  'Whitley',
#  'XinSheYang1',
#  'XinSheYang2',
#  'XinSheYang3',
#  'XinSheYang4',
#  'YaoLiu09',
#  'Zakharov',
#  'ZeroSum',
#  'CEC2005']

# %%
print("Total of functions: ", len(functions))
# Out:
# Total of functions:  108

# %% [markdown]
# Let us try the Rastrigin function and plot it

# %%
fun = bf.Rastrigin(2)
fun.plot(samples=100, resolution=125)
plt.show()

# %% [markdown]
#     Now, let us plot it in another way, through evaluations.

# %%
samples = 100

space_constraints = np.array(fun.get_search_range()).T

X, Y = np.meshgrid(np.linspace(*space_constraints[0], samples),
                   np.linspace(*space_constraints[1], samples))
Z = np.array([fun.get_function_value([x, y])
          for x, y in zip(X.ravel(), Y.ravel())]).reshape(X.shape)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, linewidth=0.5,
                antialiased=True, cmap=plt.cm.jet)
plt.show()

# %% [markdown]
# Plot another function and modify its behaviour a little

# %%
fun = bf.Ackley1(2)
fun.plot()
plt.show()

# %%
fun.set_search_range([-1.0, -1.0], [1.0, 1.0])
fun.plot()
plt.show()

# %%
fun.set_offset_function(-2)
fun.set_scale_function(2)
fun.set_noise_level(1.0)
fun.set_offset_domain([0.5, 0.5])
fun.plot()
plt.show()

# %% [markdown]
# ## 2. Module of Population (customhys.population)
# In this section, we will review the use of the population module, which is the base of the algorithms we are going to design.
#
# Let us begin by importing the module and other utilities for plotting.

# %%
from customhys import  population as pp
fun = bf.Rastrigin(2)

# %% [markdown]
# Now, we will generate a population in the search space of the previous problem. This generation can be random or following a vertex pattern:

# %%
pop = pp.Population(fun.get_search_range(), num_agents=50)
pop.initialise_positions('vertex')
# pop.initialise_positions('random')

# %% [markdown]
# Notice the difference between the internal positions of the population and the external positions to the population:

# %%
print("Internal Positions: ", pop.positions)
print("External Positions: ", pop.get_positions())
# Out:
# Internal Positions:  [[-1.         -1.        ]
#  [-1.          1.        ]
#  [ 1.         -1.        ]
#  [ 1.          1.        ]
#  [-0.92307692 -0.92307692]
#  [-0.92307692  0.92307692]
#  [ 0.92307692 -0.92307692]
#  [ 0.92307692  0.92307692]
#  [-0.84615385 -0.84615385]
#  [-0.84615385  0.84615385]
#  [ 0.84615385 -0.84615385]
#  [ 0.84615385  0.84615385]
#  [-0.76923077 -0.76923077]
#  [-0.76923077  0.76923077]
#  [ 0.76923077 -0.76923077]
#  [ 0.76923077  0.76923077]
#  [-0.69230769 -0.69230769]
#  [-0.69230769  0.69230769]
#  [ 0.69230769 -0.69230769]
#  [ 0.69230769  0.69230769]
#  [-0.61538462 -0.61538462]
#  [-0.61538462  0.61538462]
#  [ 0.61538462 -0.61538462]
#  [ 0.61538462  0.61538462]
#  [-0.53846154 -0.53846154]
#  [-0.53846154  0.53846154]
#  [ 0.53846154 -0.53846154]
#  [ 0.53846154  0.53846154]
#  [-0.46153846 -0.46153846]
#  [-0.46153846  0.46153846]
#  [ 0.46153846 -0.46153846]
#  [ 0.46153846  0.46153846]
#  [-0.38461538 -0.38461538]
#  [-0.38461538  0.38461538]
#  [ 0.38461538 -0.38461538]
#  [ 0.38461538  0.38461538]
#  [-0.30769231 -0.30769231]
#  [-0.30769231  0.30769231]
#  [ 0.30769231 -0.30769231]
#  [ 0.30769231  0.30769231]
#  [-0.23076923 -0.23076923]
#  [-0.23076923  0.23076923]
#  [ 0.23076923 -0.23076923]
#  [ 0.23076923  0.23076923]
#  [-0.15384615 -0.15384615]
#  [-0.15384615  0.15384615]
#  [ 0.15384615 -0.15384615]
#  [ 0.15384615  0.15384615]
#  [-0.07692308 -0.07692308]
#  [-0.07692308  0.07692308]]
# External Positions:  [[-5.12       -5.12      ]
#  [-5.12        5.12      ]
#  [ 5.12       -5.12      ]
#  [ 5.12        5.12      ]
#  [-4.72615385 -4.72615385]
#  [-4.72615385  4.72615385]
#  [ 4.72615385 -4.72615385]
#  [ 4.72615385  4.72615385]
#  [-4.33230769 -4.33230769]
#  [-4.33230769  4.33230769]
#  [ 4.33230769 -4.33230769]
#  [ 4.33230769  4.33230769]
#  [-3.93846154 -3.93846154]
#  [-3.93846154  3.93846154]
#  [ 3.93846154 -3.93846154]
#  [ 3.93846154  3.93846154]
#  [-3.54461538 -3.54461538]
#  [-3.54461538  3.54461538]
#  [ 3.54461538 -3.54461538]
#  [ 3.54461538  3.54461538]
#  [-3.15076923 -3.15076923]
#  [-3.15076923  3.15076923]
#  [ 3.15076923 -3.15076923]
#  [ 3.15076923  3.15076923]
#  [-2.75692308 -2.75692308]
#  [-2.75692308  2.75692308]
#  [ 2.75692308 -2.75692308]
#  [ 2.75692308  2.75692308]
#  [-2.36307692 -2.36307692]
#  [-2.36307692  2.36307692]
#  [ 2.36307692 -2.36307692]
#  [ 2.36307692  2.36307692]
#  [-1.96923077 -1.96923077]
#  [-1.96923077  1.96923077]
#  [ 1.96923077 -1.96923077]
#  [ 1.96923077  1.96923077]
#  [-1.57538462 -1.57538462]
#  [-1.57538462  1.57538462]
#  [ 1.57538462 -1.57538462]
#  [ 1.57538462  1.57538462]
#  [-1.18153846 -1.18153846]
#  [-1.18153846  1.18153846]
#  [ 1.18153846 -1.18153846]
#  [ 1.18153846  1.18153846]
#  [-0.78769231 -0.78769231]
#  [-0.78769231  0.78769231]
#  [ 0.78769231 -0.78769231]
#  [ 0.78769231  0.78769231]
#  [-0.39384615 -0.39384615]
#  [-0.39384615  0.39384615]]

# %% [markdown]
# Due to the fact that we need to evaluate the quality of each position for a given problem, we must have the function to evaluate.

# %%
pop.evaluate_fitness(lambda x: fun.get_function_value(x))
print(pop.fitness)
# Out:
# [57.84942745 57.84942745 57.84942745 57.84942745 67.65845725 67.65845725
#  67.65845725 67.65845725 67.42595459 67.42595459 67.42595459 67.42595459
#  32.4994656  32.4994656  32.4994656  32.4994656  64.34789832 64.34789832
#  64.34789832 64.34789832 28.17732858 28.17732858 28.17732858 28.17732858
#  34.33154453 34.33154453 34.33154453 34.33154453 44.21226873 44.21226873
#  44.21226873 44.21226873  8.12833712  8.12833712  8.12833712  8.12833712
#  42.76180949 42.76180949 42.76180949 42.76180949 14.45180467 14.45180467
#  14.45180467 14.45180467 16.54851609 16.54851609 16.54851609 16.54851609
#  36.02404588 36.02404588]

# %% [markdown]
# Let us see these initial positions in the search space

# %%
def show_positions(azim=-90, elev=90):
    positions = np.array(pop.get_positions())
    fitness = pop.fitness

    fig = plt.figure(figsize=(6,6))
    ax = fig.add_subplot(projection='3d', )
    ax.plot_surface(X, Y, Z, rstride=1, cstride=1, linewidth=0.5,
                    antialiased=True, cmap=plt.cm.winter, alpha=0.25)
    ax.scatter(positions[:,0], positions[:,1], pop.fitness,
               marker='o', color='r')
    ax.view_init(elev, azim)
    plt.show()

show_positions()

# %% [markdown]
# An important part of the population is the update of the particular positions, which are used by some operators.

# %%
pop.update_positions(level='population', selector='all')
pop.update_positions(level='particular', selector='all')
pop.update_positions(level='global', selector='greedy')

# %% [markdown]
# Now, let us see which is the best position among all.

# %%
print(pop.get_state())
# Out:
# x_best = [-1.96923077 -1.96923077], f_best = 8.128337122182147

# %% [markdown]
# ## 3. Module of Operators (customhys.operators)
# In this section we will see one of the most important modules, this is the one of the operators that will help us to build the desired algorithm.

# %%
from customhys import operators as op

# %% [markdown]
# Let us see the available operators:

# %%
print('Perturbadores: ', op.__all__)
# Out:
# Perturbadores:  ['local_random_walk', 'random_search', 'random_sample', 'random_flight', 'differential_mutation', 'firefly_dynamic', 'swarm_dynamic', 'gravitational_search', 'central_force_dynamic', 'spiral_dynamic', 'genetic_mutation', 'genetic_crossover']

# %%
print('Selectores: ', op.__selectors__)
# Out:
# Selectores:  ['all', 'greedy', 'metropolis', 'probabilistic']

# %% [markdown]
# Now, let us check the default collection of operators.

# %%
import pkgutil
data = pkgutil.get_data("customhys", "collections/default.txt")

for i, x in enumerate(data.decode().split("\n")[:-1]):
    print(i, x, sep=" :: ")
# Out:
# 0 :: ('random_search', {'scale': 1.0, 'distribution': 'uniform'}, 'greedy')
# 1 :: ('central_force_dynamic', {'gravity': 0.001, 'alpha': 0.01, 'beta': 1.5, 'dt': 1.0}, 'all')
# 2 :: ('central_force_dynamic', {'gravity': 0.001, 'alpha': 0.01, 'beta': 1.5, 'dt': 1.0}, 'greedy')
# 3 :: ('central_force_dynamic', {'gravity': 0.001, 'alpha': 0.01, 'beta': 1.5, 'dt': 1.0}, 'metropolis')
# 4 :: ('central_force_dynamic', {'gravity': 0.001, 'alpha': 0.01, 'beta': 1.5, 'dt': 1.0}, 'probabilistic')
# 5 :: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'all')
# 6 :: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# 7 :: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'metropolis')
# 8 :: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'probabilistic')
# 9 :: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'all')
# 10 :: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# 11 :: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'metropolis')
# 12 :: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'probabilistic')
# 13 :: ('differential_mutation', {'expression': 'current', 'num_rands': 1, 'factor': 1.0}, 'all')
# 14 :: ('differential_mutation', {'expression': 'current', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# 15 :: ('differential_mutation', {'expression': 'current', 'num_rands': 1, 'factor': 1.0}, 'metropolis')
# 16 :: ('differential_mutation', {'expression': 'current', 'num_rands': 1, 'factor': 1.0}, 'probabilistic')
# 17 :: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 1, 'factor': 1.0}, 'all')
# 18 :: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# 19 :: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 1, 'factor': 1.0}, 'metropolis')
# 20 :: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 1, 'factor': 1.0}, 'probabilistic')
# 21 :: ('differential_mutation', {'expression': 'rand-to-best', 'num_rands': 1, 'factor': 1.0}, 'all')
# 22 :: ('differential_mutation', {'expression': 'rand-to-best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# 23 :: ('differential_mutation', {'expression': 'rand-to-best', 'num_rands': 1, 'factor': 1.0}, 'metropolis')
# 24 :: ('differential_mutation', {'expression': 'rand-to-best', 'num_rands': 1, 'factor': 1.0}, 'probabilistic')
# 25 :: ('differential_mutation', {'expression': 'rand-to-best-and-current', 'num_rands': 1, 'factor': 1.0}, 'all')
# 26 :: ('differential_mutation', {'expression': 'rand-to-best-and-current', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# 27 :: ('differential_mutation', {'expression': 'rand-to-best-and-current', 'num_rands': 1, 'factor': 1.0}, 'metropolis')
# 28 :: ('differential_mutation', {'expression': 'rand-to-best-and-current', 'num_rands': 1, 'factor': 1.0}, 'probabilistic')
# 29 :: ('firefly_dynamic', {'distribution': 'uniform', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'all')
# 30 :: ('firefly_dynamic', {'distribution': 'uniform', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'greedy')
# 31 :: ('firefly_dynamic', {'distribution': 'uniform', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# 32 :: ('firefly_dynamic', {'distribution': 'uniform', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'probabilistic')
# 33 :: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'all')
# 34 :: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'greedy')
# 35 :: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# 36 :: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'probabilistic')
# 37 :: ('firefly_dynamic', {'distribution': 'levy', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'all')
# 38 :: ('firefly_dynamic', {'distribution': 'levy', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'greedy')
# 39 :: ('firefly_dynamic', {'distribution': 'levy', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# 40 :: ('firefly_dynamic', {'distribution': 'levy', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'probabilistic')
# 41 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'all')
# 42 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'greedy')
# 43 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'metropolis')
# 44 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'probabilistic')
# 45 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'all')
# 46 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'greedy')
# 47 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'metropolis')
# 48 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'probabilistic')
# 49 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'all')
# 50 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'greedy')
# 51 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'metropolis')
# 52 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'probabilistic')
# 53 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'all')
# 54 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'greedy')
# 55 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'metropolis')
# 56 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'single', 'mating_pool_factor': 0.4}, 'probabilistic')
# 57 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'all')
# 58 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'greedy')
# 59 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'metropolis')
# 60 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'probabilistic')
# 61 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'all')
# 62 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'greedy')
# 63 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'metropolis')
# 64 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'probabilistic')
# 65 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'all')
# 66 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'greedy')
# 67 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'metropolis')
# 68 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'probabilistic')
# 69 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'all')
# 70 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'greedy')
# 71 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'metropolis')
# 72 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'two', 'mating_pool_factor': 0.4}, 'probabilistic')
# 73 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'all')
# 74 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'greedy')
# 75 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'metropolis')
# 76 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# 77 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'all')
# 78 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'greedy')
# 79 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'metropolis')
# 80 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# 81 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'all')
# 82 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'greedy')
# 83 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'metropolis')
# 84 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# 85 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'all')
# 86 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'greedy')
# 87 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'metropolis')
# 88 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# 89 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'all')
# 90 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'greedy')
# 91 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'metropolis')
# 92 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'probabilistic')
# 93 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'all')
# 94 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'greedy')
# 95 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'metropolis')
# 96 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'probabilistic')
# 97 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'all')
# 98 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'greedy')
# 99 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'metropolis')
# 100 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'probabilistic')
# 101 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'all')
# 102 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'greedy')
# 103 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'metropolis')
# 104 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'blend', 'mating_pool_factor': 0.4}, 'probabilistic')
# 105 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'all')
# 106 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'greedy')
# 107 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'metropolis')
# 108 :: ('genetic_crossover', {'pairing': 'rank', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'probabilistic')
# 109 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'all')
# 110 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'greedy')
# 111 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'metropolis')
# 112 :: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'probabilistic')
# 113 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'all')
# 114 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'greedy')
# 115 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'metropolis')
# 116 :: ('genetic_crossover', {'pairing': 'random', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'probabilistic')
# 117 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'all')
# 118 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'greedy')
# 119 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'metropolis')
# 120 :: ('genetic_crossover', {'pairing': 'tournament_2_100', 'crossover': 'linear_0.5_0.5', 'mating_pool_factor': 0.4}, 'probabilistic')
# 121 :: ('genetic_mutation', {'scale': 1.0, 'elite_rate': 0.1, 'mutation_rate': 0.25, 'distribution': 'uniform'}, 'all')
# 122 :: ('genetic_mutation', {'scale': 1.0, 'elite_rate': 0.1, 'mutation_rate': 0.25, 'distribution': 'uniform'}, 'greedy')
# 123 :: ('genetic_mutation', {'scale': 1.0, 'elite_rate': 0.1, 'mutation_rate': 0.25, 'distribution': 'uniform'}, 'metropolis')
# 124 :: ('genetic_mutation', {'scale': 1.0, 'elite_rate': 0.1, 'mutation_rate': 0.25, 'distribution': 'uniform'}, 'probabilistic')
# 125 :: ('genetic_mutation', {'scale': 1.0, 'elite_rate': 0.1, 'mutation_rate': 0.25, 'distribution': 'gaussian'}, 'all')
# 126 :: ('genetic_mutation', {'scale': 1.0, 'elite_rate': 0.1, 'mutation_rate': 0.25, 'distribution': 'gaussian'}, 'greedy')
# 127 :: ('genetic_mutation', {'scale': 1.0, 'elite_rate': 0.1, 'mutation_rate': 0.25, 'distribution': 'gaussian'}, 'metropolis')
# 128 :: ('genetic_mutation', {'scale': 1.0, 'elite_rate': 0.1, 'mutation_rate': 0.25, 'distribution': 'gaussian'}, 'probabilistic')
# 129 :: ('genetic_mutation', {'scale': 1.0, 'elite_rate': 0.1, 'mutation_rate': 0.25, 'distribution': 'levy'}, 'all')
# 130 :: ('genetic_mutation', {'scale': 1.0, 'elite_rate': 0.1, 'mutation_rate': 0.25, 'distribution': 'levy'}, 'greedy')
# 131 :: ('genetic_mutation', {'scale': 1.0, 'elite_rate': 0.1, 'mutation_rate': 0.25, 'distribution': 'levy'}, 'metropolis')
# 132 :: ('genetic_mutation', {'scale': 1.0, 'elite_rate': 0.1, 'mutation_rate': 0.25, 'distribution': 'levy'}, 'probabilistic')
# 133 :: ('gravitational_search', {'gravity': 1.0, 'alpha': 0.02}, 'all')
# 134 :: ('gravitational_search', {'gravity': 1.0, 'alpha': 0.02}, 'greedy')
# 135 :: ('gravitational_search', {'gravity': 1.0, 'alpha': 0.02}, 'metropolis')
# 136 :: ('gravitational_search', {'gravity': 1.0, 'alpha': 0.02}, 'probabilistic')
# 137 :: ('random_flight', {'scale': 1.0, 'distribution': 'levy', 'beta': 1.5}, 'all')
# 138 :: ('random_flight', {'scale': 1.0, 'distribution': 'levy', 'beta': 1.5}, 'greedy')
# 139 :: ('random_flight', {'scale': 1.0, 'distribution': 'levy', 'beta': 1.5}, 'metropolis')
# 140 :: ('random_flight', {'scale': 1.0, 'distribution': 'levy', 'beta': 1.5}, 'probabilistic')
# 141 :: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'all')
# 142 :: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'greedy')
# 143 :: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'metropolis')
# 144 :: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# 145 :: ('random_flight', {'scale': 1.0, 'distribution': 'gaussian'}, 'all')
# 146 :: ('random_flight', {'scale': 1.0, 'distribution': 'gaussian'}, 'greedy')
# 147 :: ('random_flight', {'scale': 1.0, 'distribution': 'gaussian'}, 'metropolis')
# 148 :: ('random_flight', {'scale': 1.0, 'distribution': 'gaussian'}, 'probabilistic')
# 149 :: ('local_random_walk', {'probability': 0.75, 'scale': 1.0, 'distribution': 'uniform'}, 'all')
# 150 :: ('local_random_walk', {'probability': 0.75, 'scale': 1.0, 'distribution': 'uniform'}, 'greedy')
# 151 :: ('local_random_walk', {'probability': 0.75, 'scale': 1.0, 'distribution': 'uniform'}, 'metropolis')
# 152 :: ('local_random_walk', {'probability': 0.75, 'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# 153 :: ('local_random_walk', {'probability': 0.75, 'scale': 1.0, 'distribution': 'gaussian'}, 'all')
# 154 :: ('local_random_walk', {'probability': 0.75, 'scale': 1.0, 'distribution': 'gaussian'}, 'greedy')
# 155 :: ('local_random_walk', {'probability': 0.75, 'scale': 1.0, 'distribution': 'gaussian'}, 'metropolis')
# 156 :: ('local_random_walk', {'probability': 0.75, 'scale': 1.0, 'distribution': 'gaussian'}, 'probabilistic')
# 157 :: ('local_random_walk', {'probability': 0.75, 'scale': 1.0, 'distribution': 'levy'}, 'all')
# 158 :: ('local_random_walk', {'probability': 0.75, 'scale': 1.0, 'distribution': 'levy'}, 'greedy')
# 159 :: ('local_random_walk', {'probability': 0.75, 'scale': 1.0, 'distribution': 'levy'}, 'metropolis')
# 160 :: ('local_random_walk', {'probability': 0.75, 'scale': 1.0, 'distribution': 'levy'}, 'probabilistic')
# 161 :: ('random_sample', {}, 'all')
# 162 :: ('random_sample', {}, 'greedy')
# 163 :: ('random_sample', {}, 'metropolis')
# 164 :: ('random_sample', {}, 'probabilistic')
# 165 :: ('random_search', {'scale': 0.01, 'distribution': 'uniform'}, 'all')
# 166 :: ('random_search', {'scale': 0.01, 'distribution': 'uniform'}, 'greedy')
# 167 :: ('random_search', {'scale': 0.01, 'distribution': 'uniform'}, 'metropolis')
# 168 :: ('random_search', {'scale': 0.01, 'distribution': 'uniform'}, 'probabilistic')
# 169 :: ('random_search', {'scale': 0.01, 'distribution': 'gaussian'}, 'all')
# 170 :: ('random_search', {'scale': 0.01, 'distribution': 'gaussian'}, 'greedy')
# 171 :: ('random_search', {'scale': 0.01, 'distribution': 'gaussian'}, 'metropolis')
# 172 :: ('random_search', {'scale': 0.01, 'distribution': 'gaussian'}, 'probabilistic')
# 173 :: ('random_search', {'scale': 0.01, 'distribution': 'levy'}, 'all')
# 174 :: ('random_search', {'scale': 0.01, 'distribution': 'levy'}, 'greedy')
# 175 :: ('random_search', {'scale': 0.01, 'distribution': 'levy'}, 'metropolis')
# 176 :: ('random_search', {'scale': 0.01, 'distribution': 'levy'}, 'probabilistic')
# 177 :: ('spiral_dynamic', {'radius': 0.9, 'angle': 22.5, 'sigma': 0.1}, 'all')
# 178 :: ('spiral_dynamic', {'radius': 0.9, 'angle': 22.5, 'sigma': 0.1}, 'greedy')
# 179 :: ('spiral_dynamic', {'radius': 0.9, 'angle': 22.5, 'sigma': 0.1}, 'metropolis')
# 180 :: ('spiral_dynamic', {'radius': 0.9, 'angle': 22.5, 'sigma': 0.1}, 'probabilistic')
# 181 :: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'uniform'}, 'all')
# 182 :: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'uniform'}, 'greedy')
# 183 :: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'uniform'}, 'metropolis')
# 184 :: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'uniform'}, 'probabilistic')
# 185 :: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'all')
# 186 :: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'greedy')
# 187 :: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'metropolis')
# 188 :: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# 189 :: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'levy'}, 'all')
# 190 :: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'levy'}, 'greedy')
# 191 :: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'levy'}, 'metropolis')
# 192 :: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'levy'}, 'probabilistic')
# 193 :: ('swarm_dynamic', {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'constriction', 'distribution': 'uniform'}, 'all')
# 194 :: ('swarm_dynamic', {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'constriction', 'distribution': 'uniform'}, 'greedy')
# 195 :: ('swarm_dynamic', {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'constriction', 'distribution': 'uniform'}, 'metropolis')
# 196 :: ('swarm_dynamic', {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'constriction', 'distribution': 'uniform'}, 'probabilistic')
# 197 :: ('swarm_dynamic', {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'constriction', 'distribution': 'gaussian'}, 'all')
# 198 :: ('swarm_dynamic', {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'constriction', 'distribution': 'gaussian'}, 'greedy')
# 199 :: ('swarm_dynamic', {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'constriction', 'distribution': 'gaussian'}, 'metropolis')
# 200 :: ('swarm_dynamic', {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'constriction', 'distribution': 'gaussian'}, 'probabilistic')
# 201 :: ('swarm_dynamic', {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'constriction', 'distribution': 'levy'}, 'all')
# 202 :: ('swarm_dynamic', {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'constriction', 'distribution': 'levy'}, 'greedy')
# 203 :: ('swarm_dynamic', {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'constriction', 'distribution': 'levy'}, 'metropolis')
# 204 :: ('swarm_dynamic', {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'constriction', 'distribution': 'levy'}, 'probabilistic')

# %%
dop = [eval(x) for x in data.decode().split("\n")[:-1]]
pd.DataFrame(dop, columns=['Perturbator', 'Parameters', 'Selector'])
# Out:
#                Perturbator                                         Parameters  \
# 0            random_search          {'scale': 1.0, 'distribution': 'uniform'}
# 1    central_force_dynamic  {'gravity': 0.001, 'alpha': 0.01, 'beta': 1.5,...
# 2    central_force_dynamic  {'gravity': 0.001, 'alpha': 0.01, 'beta': 1.5,...
# 3    central_force_dynamic  {'gravity': 0.001, 'alpha': 0.01, 'beta': 1.5,...
# 4    central_force_dynamic  {'gravity': 0.001, 'alpha': 0.01, 'beta': 1.5,...
# ..                     ...                                                ...
# 200          swarm_dynamic  {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf...
# 201          swarm_dynamic  {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf...
# 202          swarm_dynamic  {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf...
# 203          swarm_dynamic  {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf...
# 204          swarm_dynamic  {'factor': 1.0, 'self_conf': 2.54, 'swarm_conf...
#
#           Selector
# 0           greedy
# 1              all
# 2           greedy
# 3       metropolis
# 4    probabilistic
# ..             ...
# 200  probabilistic
# 201            all
# 202         greedy
# 203     metropolis
# 204  probabilistic
#
# [205 rows x 3 columns]

# %% [markdown]
# You can also generate a collection automatically and then distil it in your favourite text editor.

# %%
op_task = op.obtain_operators(num_vals=5)
print(op_task.__len__(), op_task)
# Out:
# 15 [('random_search', {'scale': [1.0], 'distribution': ['uniform']}, ['greedy']), ('central_force_dynamic', {'gravity': [0.0, 0.0025, 0.005, 0.0075, 0.01], 'alpha': [0.0, 0.0025, 0.005, 0.0075, 0.01], 'beta': [1.0, 1.25, 1.5, 1.75, 2.0], 'dt': [0.0, 0.5, 1.0, 1.5, 2.0]}, ['all', 'greedy', 'metropolis', 'probabilistic']), ('differential_crossover', {'crossover_rate': [0.0, 0.25, 0.5, 0.75, 1.0], 'version': ['binomial', 'exponential']}, ['all', 'greedy', 'metropolis', 'probabilistic']), ('differential_mutation', {'expression': ['rand', 'best', 'current', 'current-to-best', 'rand-to-best', 'rand-to-best-and-current'], 'num_rands': [1, 2, 3], 'factor': [0.0, 0.625, 1.25, 1.875, 2.5]}, ['all', 'greedy', 'metropolis', 'probabilistic']), ('firefly_dynamic', {'distribution': ['uniform', 'gaussian', 'levy'], 'alpha': [0.0, 0.125, 0.25, 0.375, 0.5], 'beta': [0.01, 0.2575, 0.505, 0.7525, 1.0], 'gamma': [1.0, 250.75, 500.5, 750.25, 1000.0]}, ['all', 'greedy', 'metropolis', 'probabilistic']), ('genetic_crossover', {'pairing': ['rank', 'cost', 'random', 'tournament_2_100', 'tournament_2_75', 'tournament_2_50', 'tournament_3_100', 'tournament_3_75', 'tournament_3_50'], 'crossover': ['single', 'two', 'uniform', 'blend', 'linear_0.5_0.5'], 'mating_pool_factor': [0.1, 0.30000000000000004, 0.5, 0.7000000000000001, 0.9]}, ['all', 'greedy', 'metropolis', 'probabilistic']), ('genetic_mutation', {'scale': [0.01, 0.2575, 0.505, 0.7525, 1.0], 'elite_rate': [0.0, 0.225, 0.45, 0.675, 0.9], 'mutation_rate': [0.1, 0.30000000000000004, 0.5, 0.7000000000000001, 0.9], 'distribution': ['uniform', 'gaussian', 'levy']}, ['all', 'greedy', 'metropolis', 'probabilistic']), ('gravitational_search', {'gravity': [0.0, 0.25, 0.5, 0.75, 1.0], 'alpha': [0.0, 0.01, 0.02, 0.03, 0.04]}, ['all', 'greedy', 'metropolis', 'probabilistic']), ('random_flight', {'scale': [0.01, 0.2575, 0.505, 0.7525, 1.0], 'distribution': ['levy'], 'beta': [1.0, 1.25, 1.5, 1.75, 2.0]}, ['all', 'greedy', 'metropolis', 'probabilistic']), ('random_flight', {'scale': [0.01, 0.2575, 0.505, 0.7525, 1.0], 'distribution': ['uniform', 'gaussian']}, ['all', 'greedy', 'metropolis', 'probabilistic']), ('local_random_walk', {'probability': [0.01, 0.255, 0.5, 0.745, 0.99], 'scale': [0.01, 0.2575, 0.505, 0.7525, 1.0], 'distribution': ['uniform', 'gaussian', 'levy']}, ['all', 'greedy', 'metropolis', 'probabilistic']), ('random_sample', {}, ['all', 'greedy', 'metropolis', 'probabilistic']), ('random_search', {'scale': [0.01, 0.2575, 0.505, 0.7525, 1.0], 'distribution': ['uniform', 'gaussian', 'levy']}, ['all', 'greedy', 'metropolis', 'probabilistic']), ('spiral_dynamic', {'radius': [0.001, 0.2505, 0.5, 0.7494999999999999, 0.999], 'angle': [0.0, 45.0, 90.0, 135.0, 180.0], 'sigma': [0.0, 0.125, 0.25, 0.375, 0.5]}, ['all', 'greedy', 'metropolis', 'probabilistic']), ('swarm_dynamic', {'factor': [0.01, 0.2575, 0.505, 0.7525, 1.0], 'self_conf': [0.01, 1.2550000000000001, 2.5, 3.745, 4.99], 'swarm_conf': [0.01, 1.2550000000000001, 2.5, 3.745, 4.99], 'version': ['inertial', 'constriction'], 'distribution': ['uniform', 'gaussian', 'levy']}, ['all', 'greedy', 'metropolis', 'probabilistic'])]

# %%
op.build_operators(heuristics=op_task, file_name='op_tutorial')
# Out:
# random_search: parameters=2, combinations:1
# central_force_dynamic: parameters=4, combinations:625
# differential_crossover: parameters=2, combinations:10
# differential_mutation: parameters=3, combinations:90
# firefly_dynamic: parameters=4, combinations:375
# genetic_crossover: parameters=3, combinations:225
# genetic_mutation: parameters=4, combinations:375
# gravitational_search: parameters=2, combinations:25
# random_flight: parameters=3, combinations:25
# random_flight: parameters=2, combinations:10
# local_random_walk: parameters=3, combinations:75
# random_sample: parameters=0, combinations:4
# random_search: parameters=2, combinations:15
# spiral_dynamic: parameters=3, combinations:125
# swarm_dynamic: parameters=5, combinations:750
# ----------------------------------------------------
# TOTAL: families=15, operators=10917

# %%
with open("collections/op_tutorial.txt") as file:
    auto_operators = file.read()

print(f"Collection size: {auto_operators.__len__()}")
np.random.choice(auto_operators.split('\n'), 5)
# Out:
# Collection size: 1268903
# array(["('central_force_dynamic', {'gravity': 0.0, 'alpha': 0.0, 'beta': 1.5, 'dt': 2.0}, 'greedy')",
#        "('swarm_dynamic', {'factor': 0.505, 'self_conf': 0.01, 'swarm_conf': 1.2550000000000001, 'version': 'constriction', 'distribution': 'levy'}, 'greedy')",
#        "('firefly_dynamic', {'distribution': 'levy', 'alpha': 0.0, 'beta': 0.7525, 'gamma': 750.25}, 'probabilistic')",
#        "('genetic_crossover', {'pairing': 'tournament_2_75', 'crossover': 'single', 'mating_pool_factor': 0.5}, 'greedy')",
#        "('swarm_dynamic', {'factor': 0.505, 'self_conf': 0.01, 'swarm_conf': 1.2550000000000001, 'version': 'inertial', 'distribution': 'gaussian'}, 'metropolis')"],
#       dtype='<U176')

# %% [markdown]
# Such a collection can be used as follows:

# %%
print(dop[1])

op_to_test = op.process_operators([dop[1]])
print(op_to_test)

op_to_exect = "op.{}(pop,{}".format(*op_to_test[0][0].split('('))
print(op_to_exect)
# Out:
# ('central_force_dynamic', {'gravity': 0.001, 'alpha': 0.01, 'beta': 1.5, 'dt': 1.0}, 'all')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('central_force_dynamic', {'gravity': 0.001, 'alpha': 0.01, 'beta': 1.5, 'dt': 1.0}, 'all')
# --- LOG: process_operators finalizado com sucesso ---
# (['central_force_dynamic(gravity=0.001,alpha=0.01,beta=1.5,dt=1.0)'], ['all'])
# op.central_force_dynamic(pop,gravity=0.001,alpha=0.01,beta=1.5,dt=1.0)

# %%
# Initial population
pop.initialise_positions('random')

# Evaluate the initial positions
pop.evaluate_fitness(lambda x: fun.get_function_value(x))

# Update the positions and fitness
pop.update_positions(level='population', selector='all')
pop.update_positions(level='global', selector='greedy')

# Save the initial state
history = [pop.fitness.copy()]

for iteration in range(1000):
    # Apply the perturbation heuristic
    # exec(op_to_exect)
    op.central_force_dynamic(pop, alpha=0.9, beta=0.45)
    
    # Evaluate the new positions
    pop.evaluate_fitness(lambda x: fun.get_function_value(x))

    # Choose random selectors (alpha version)
    selector = list(np.random.choice(['direct', 'greedy', 'probabilistic'], pop.num_agents))
    #selector = 'direct'

    # Update the positions
    pop.update_positions(level='population', selector=selector)
    pop.update_positions(level='global')   
    
    # Save the fitness
    history.append(pop.fitness.copy())

    if iteration % 100 == 0:
        print(f"Iteration: {iteration} ::", pop.get_state())
        show_positions()
# Out:
# Iteration: 0 :: x_best = [0.93668533 1.89323883], f_best = 7.409401971206293
# Iteration: 100 :: x_best = [-0.01319171  0.00064629], f_best = 0.03458761196552018
# Iteration: 200 :: x_best = [-0.01319171  0.00064629], f_best = 0.03458761196552018
# Iteration: 300 :: x_best = [-0.01319171  0.00064629], f_best = 0.03458761196552018
# Iteration: 400 :: x_best = [-0.01319171  0.00064629], f_best = 0.03458761196552018
# Iteration: 500 :: x_best = [-0.01319171  0.00064629], f_best = 0.03458761196552018
# Iteration: 600 :: x_best = [-0.01319171  0.00064629], f_best = 0.03458761196552018
# Iteration: 700 :: x_best = [-0.01319171  0.00064629], f_best = 0.03458761196552018
# Iteration: 800 :: x_best = [-0.01319171  0.00064629], f_best = 0.03458761196552018
# Iteration: 900 :: x_best = [-0.01319171  0.00064629], f_best = 0.03458761196552018

# %% [markdown]
# Let us plot the historical values of the fitness

# %%
# Process the historical values
history = np.array(history) + 1

plt.figure()
# plot in gray scale to after plot some statistics above
plt.plot(history, color='gray', alpha=0.15)
plt.plot(history.max(axis=1), lw=1, label='Max')
plt.plot(np.quantile(history, 0.75, axis=1), lw=1, label='Q3')
plt.plot(history.mean(axis=1), lw=1, label='Mean')
plt.plot(np.median(history, axis=1), lw=1, label='Median')
plt.plot(np.quantile(history, 0.25, axis=1), lw=1, label='Q1')
plt.plot(history.min(axis=1), lw=1, label='Min')
#plt.plot(history.std(axis=1), lw=2, label='Std')

plt.legend(frameon=False)
plt.xlabel('Iteration'), plt.ylabel('Fitness')
plt.tight_layout()
plt.xscale('log')
plt.yscale('log')
plt.show()

# %% [markdown]
# ## 4. Module of Metaheuristics (customhys.metaheuristic)
# In this section, we will see how to use the module to build a metaheuristics.

# %%
from customhys import metaheuristic as mh
fun = bf.Rastrigin(3)
prob = fun.get_formatted_problem()

prob
# Out:
# {'function': <function customhys.benchmark_func.BasicProblem.get_formatted_problem.<locals>.<lambda>(x)>,
#  'boundaries': (array([-5.12, -5.12, -5.12]), array([5.12, 5.12, 5.12])),
#  'is_constrained': True,
#  'features': '110',
#  'func_name': 'Rastrigin',
#  'dimensions': 3}

# %%
heur = [( # Search operator 1
    'differential_mutation',  # Perturbator
    {  # Parameters
        'expression': 'current-to-best',
        'num_rands': 2,
        'factor': 1.0},
    'greedy'  # Selector
), (  # Search operator 2
    'differential_crossover',  # Perturbator
    {  # Parameters
        'crossover_rate': 0.2,
        'version': 'binomial'
    },
    'greedy'  # Selector
)]

met = mh.Metaheuristic(prob, heur, num_iterations=1000)
met.verbose = True
met.run()
print('x_best = {}, f_best = {}'.format(*met.get_solution()))
# Out:
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 1000, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 3 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
#
# Search operators to employ:
# differential_mutation(expression='current-to-best',num_rands=2,factor=1.0) with greedy
# differential_crossover(crossover_rate=0.2,version='binomial') with greedy
# --------------------------------------------------
# 1
# pop. radius: 1.6731949263823591
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 2
# pop. radius: 1.6230820429625172
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 3
# pop. radius: 1.637637580762929
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 4
# pop. radius: 1.4149402983362545
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 5
# pop. radius: 1.4395325778488057
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 6
# pop. radius: 1.4938832235942554
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 7
# pop. radius: 1.478990694551619
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 8
# pop. radius: 1.4521268473315865
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 9
# pop. radius: 1.437786635614667
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 10
# pop. radius: 1.437786635614667
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 11
# pop. radius: 1.4549460567534138
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 12
# pop. radius: 1.457548911066453
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 13
# pop. radius: 1.3318352111992344
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 14
# pop. radius: 1.321407483863827
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 15
# pop. radius: 1.3193528025918129
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 16
# pop. radius: 1.3084027834250678
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 17
# pop. radius: 1.478077703075753
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 18
# pop. radius: 1.4446413155907147
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 19
# pop. radius: 1.4446413155907147
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 20
# pop. radius: 1.4446413155907147
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 21
# pop. radius: 1.441487643765646
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 22
# pop. radius: 1.441487643765646
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 23
# pop. radius: 1.4159377124100032
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 24
# pop. radius: 1.4159377124100032
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 25
# pop. radius: 1.4185441696548948
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 26
# pop. radius: 1.4185441696548948
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 27
# pop. radius: 1.4185441696548948
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 28
# pop. radius: 1.4051150337800358
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 29
# pop. radius: 1.392537105632412
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 30
# pop. radius: 1.1734398764388252
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 31
# pop. radius: 1.1734398764388252
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 32
# pop. radius: 1.1734398764388252
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 33
# pop. radius: 1.159858585646608
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 34
# pop. radius: 1.1764038758674247
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 35
# pop. radius: 1.1764038758674247
# x_best = [-0.08765609 -0.78801988 -1.01991985], f_best = 10.859641902997364
# 36
# pop. radius: 1.1732796026173113
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 37
# pop. radius: 1.1732796026173113
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 38
# pop. radius: 1.1732796026173113
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 39
# pop. radius: 1.1972310237798431
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 40
# pop. radius: 1.1972310237798431
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 41
# pop. radius: 1.1933970071519455
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 42
# pop. radius: 1.1933970071519455
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 43
# pop. radius: 1.1627112888587725
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 44
# pop. radius: 1.157501206077657
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 45
# pop. radius: 1.157501206077657
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 46
# pop. radius: 1.157501206077657
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 47
# pop. radius: 1.157501206077657
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 48
# pop. radius: 1.1961396665998147
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 49
# pop. radius: 1.1961396665998147
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 50
# pop. radius: 1.1961396665998147
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 51
# pop. radius: 1.161211913216273
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 52
# pop. radius: 1.161211913216273
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 53
# pop. radius: 1.161211913216273
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 54
# pop. radius: 1.185117533041623
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 55
# pop. radius: 1.185117533041623
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 56
# pop. radius: 1.20449105755273
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 57
# pop. radius: 1.2026925525683128
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 58
# pop. radius: 1.2026925525683128
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 59
# pop. radius: 1.1967339385742868
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 60
# pop. radius: 1.1967339385742868
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 61
# pop. radius: 1.1720021004316592
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 62
# pop. radius: 1.160455341360214
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 63
# pop. radius: 1.160455341360214
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 64
# pop. radius: 1.160455341360214
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 65
# pop. radius: 1.1702987626436265
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 66
# pop. radius: 1.1702987626436265
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 67
# pop. radius: 1.2010784133583454
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 68
# pop. radius: 1.2010784133583454
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 69
# pop. radius: 1.2218282702066356
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 70
# pop. radius: 1.1587555387706803
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 71
# pop. radius: 1.1587555387706803
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 72
# pop. radius: 1.1587555387706803
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 73
# pop. radius: 1.1538631529426995
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 74
# pop. radius: 1.1538631529426995
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 75
# pop. radius: 1.1538631529426995
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 76
# pop. radius: 1.1538631529426995
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 77
# pop. radius: 1.1538631529426995
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 78
# pop. radius: 1.1538631529426995
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 79
# pop. radius: 1.1225752816593182
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 80
# pop. radius: 1.1226025283320533
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 81
# pop. radius: 1.094922088764615
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 82
# pop. radius: 1.0921522673416515
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 83
# pop. radius: 1.0921522673416515
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 84
# pop. radius: 1.0921522673416515
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 85
# pop. radius: 1.0921522673416515
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 86
# pop. radius: 1.0921522673416515
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 87
# pop. radius: 1.0921522673416515
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 88
# pop. radius: 1.0792700700535394
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 89
# pop. radius: 1.0792700700535394
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 90
# pop. radius: 1.0792700700535394
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 91
# pop. radius: 1.0792700700535394
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 92
# pop. radius: 1.0792700700535394
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 93
# pop. radius: 1.0792700700535394
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 94
# pop. radius: 1.0612091438897517
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 95
# pop. radius: 1.0612091438897517
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 96
# pop. radius: 1.0598659301852438
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 97
# pop. radius: 1.0598659301852438
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 98
# pop. radius: 1.0669467363851592
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 99
# pop. radius: 1.0669467363851592
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 100
# pop. radius: 1.0669467363851592
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 101
# pop. radius: 1.0669467363851592
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 102
# pop. radius: 1.0669467363851592
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 103
# pop. radius: 1.0669467363851592
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 104
# pop. radius: 1.0512145156056725
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 105
# pop. radius: 1.0607062977387587
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 106
# pop. radius: 1.0458153505472196
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 107
# pop. radius: 1.0458153505472196
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 108
# pop. radius: 1.0458153505472196
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 109
# pop. radius: 1.0458153505472196
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 110
# pop. radius: 1.025050075396012
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 111
# pop. radius: 1.025050075396012
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 112
# pop. radius: 1.025050075396012
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 113
# pop. radius: 1.025050075396012
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 114
# pop. radius: 1.040022587900974
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 115
# pop. radius: 1.040022587900974
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 116
# pop. radius: 1.040022587900974
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 117
# pop. radius: 1.0396378245957296
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 118
# pop. radius: 1.0396378245957296
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 119
# pop. radius: 1.054064471485851
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 120
# pop. radius: 0.8281021826716357
# x_best = [-0.0703247  -1.01424273  0.87902052], f_best = 5.559341243866548
# 121
# pop. radius: 0.826903945285664
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 122
# pop. radius: 0.826903945285664
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 123
# pop. radius: 0.826903945285664
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 124
# pop. radius: 0.826903945285664
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 125
# pop. radius: 0.826903945285664
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 126
# pop. radius: 0.8330059641433216
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 127
# pop. radius: 0.8330059641433216
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 128
# pop. radius: 0.8330059641433216
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 129
# pop. radius: 0.8330059641433216
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 130
# pop. radius: 0.8330059641433216
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 131
# pop. radius: 0.8330059641433216
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 132
# pop. radius: 0.8330059641433216
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 133
# pop. radius: 0.8330059641433216
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 134
# pop. radius: 0.8330059641433216
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 135
# pop. radius: 0.8330059641433216
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 136
# pop. radius: 0.8330059641433216
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 137
# pop. radius: 0.8543884170430317
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 138
# pop. radius: 0.8543884170430317
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 139
# pop. radius: 0.8543884170430317
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 140
# pop. radius: 0.8543884170430317
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 141
# pop. radius: 0.8543884170430317
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 142
# pop. radius: 0.8542362403821137
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 143
# pop. radius: 0.8542362403821137
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 144
# pop. radius: 0.8542362403821137
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 145
# pop. radius: 0.8542362403821137
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 146
# pop. radius: 0.8542362403821137
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 147
# pop. radius: 0.8709128544565268
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 148
# pop. radius: 0.8709026220166394
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 149
# pop. radius: 0.8709026220166394
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 150
# pop. radius: 0.8447814552359446
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 151
# pop. radius: 0.8447814552359446
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 152
# pop. radius: 0.8468764961934085
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 153
# pop. radius: 0.868040221850742
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 154
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 155
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 156
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 157
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 158
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 159
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 160
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 161
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 162
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 163
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 164
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 165
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 166
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 167
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 168
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 169
# pop. radius: 0.8756311871357205
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 170
# pop. radius: 0.8810866059402451
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 171
# pop. radius: 0.8763270326715098
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 172
# pop. radius: 0.8763270326715098
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 173
# pop. radius: 0.8763270326715098
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 174
# pop. radius: 0.8763270326715098
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 175
# pop. radius: 0.8763270326715098
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 176
# pop. radius: 0.8763270326715098
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 177
# pop. radius: 0.8753353015649373
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 178
# pop. radius: 0.8753353015649373
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 179
# pop. radius: 0.8753353015649373
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 180
# pop. radius: 0.8753353015649373
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 181
# pop. radius: 0.8772822168745191
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 182
# pop. radius: 0.8171087753717919
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 183
# pop. radius: 0.8171087753717919
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 184
# pop. radius: 0.8133244713892281
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 185
# pop. radius: 0.8264957678692583
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 186
# pop. radius: 0.8264957678692583
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 187
# pop. radius: 0.8264957678692583
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 188
# pop. radius: 0.8264957678692583
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 189
# pop. radius: 0.8264957678692583
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 190
# pop. radius: 0.8362363407931724
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 191
# pop. radius: 0.8362363407931724
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 192
# pop. radius: 0.8218337919557803
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 193
# pop. radius: 0.8218337919557803
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 194
# pop. radius: 0.8110959392719458
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 195
# pop. radius: 0.8110959392719458
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 196
# pop. radius: 0.8061102257441952
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 197
# pop. radius: 0.8061102257441952
# x_best = [ 0.93706891 -0.95507316  0.05254924], f_best = 3.500559142538698
# 198
# pop. radius: 0.8098979509960628
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 199
# pop. radius: 0.8098979509960628
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 200
# pop. radius: 0.8098979509960628
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 201
# pop. radius: 0.8098979509960628
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 202
# pop. radius: 0.7105887813339793
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 203
# pop. radius: 0.7105887813339793
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 204
# pop. radius: 0.7105887813339793
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 205
# pop. radius: 0.7105887813339793
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 206
# pop. radius: 0.7053517549375299
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 207
# pop. radius: 0.7067787480092388
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 208
# pop. radius: 0.7067787480092388
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 209
# pop. radius: 0.6815548180433176
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 210
# pop. radius: 0.6815548180433176
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 211
# pop. radius: 0.6858857991589318
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 212
# pop. radius: 0.6858857991589318
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 213
# pop. radius: 0.6858857991589318
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 214
# pop. radius: 0.6858857991589318
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 215
# pop. radius: 0.6858857991589318
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 216
# pop. radius: 0.6858857991589318
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 217
# pop. radius: 0.6857068003031795
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 218
# pop. radius: 0.6857068003031795
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 219
# pop. radius: 0.6857068003031795
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 220
# pop. radius: 0.6857068003031795
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 221
# pop. radius: 0.663436990474149
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 222
# pop. radius: 0.663436990474149
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 223
# pop. radius: 0.663436990474149
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 224
# pop. radius: 0.6705506187884441
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 225
# pop. radius: 0.6705506187884441
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 226
# pop. radius: 0.6705506187884441
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 227
# pop. radius: 0.6705506187884441
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 228
# pop. radius: 0.6705506187884441
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 229
# pop. radius: 0.6686275584601526
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 230
# pop. radius: 0.6744702197451805
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 231
# pop. radius: 0.6744702197451805
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 232
# pop. radius: 0.6744702197451805
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 233
# pop. radius: 0.6744702197451805
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 234
# pop. radius: 0.6760609269854277
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 235
# pop. radius: 0.6760609269854277
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 236
# pop. radius: 0.6760609269854277
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 237
# pop. radius: 0.6760609269854277
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 238
# pop. radius: 0.6760609269854277
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 239
# pop. radius: 0.6760609269854277
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 240
# pop. radius: 0.6760609269854277
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 241
# pop. radius: 0.6760609269854277
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 242
# pop. radius: 0.6760609269854277
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 243
# pop. radius: 0.5811858907120343
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 244
# pop. radius: 0.5811858907120343
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 245
# pop. radius: 0.5811914220133759
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 246
# pop. radius: 0.5811914220133759
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 247
# pop. radius: 0.5823090060042241
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 248
# pop. radius: 0.5823090060042241
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 249
# pop. radius: 0.5823090060042241
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 250
# pop. radius: 0.5823090060042241
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 251
# pop. radius: 0.5823090060042241
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 252
# pop. radius: 0.5803230911948338
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 253
# pop. radius: 0.5803230911948338
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 254
# pop. radius: 0.5803230911948338
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 255
# pop. radius: 0.5803230911948338
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 256
# pop. radius: 0.5803230911948338
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 257
# pop. radius: 0.5833599026311896
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 258
# pop. radius: 0.5833855916486488
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 259
# pop. radius: 0.5831529632679121
# x_best = [-1.04667483  0.06558644 -0.05239712], f_best = 2.9037328294021556
# 260
# pop. radius: 0.5836417740875461
# x_best = [-0.08739959 -0.03946817  0.02243071], f_best = 1.885066533207059
# 261
# pop. radius: 0.5836417740875461
# x_best = [-0.08739959 -0.03946817  0.02243071], f_best = 1.885066533207059
# 262
# pop. radius: 0.5836417740875461
# x_best = [-0.08739959 -0.03946817  0.02243071], f_best = 1.885066533207059
# 263
# pop. radius: 0.5836417740875461
# x_best = [-0.08739959 -0.03946817  0.02243071], f_best = 1.885066533207059
# 264
# pop. radius: 0.5850192456986276
# x_best = [-0.08739959 -0.03946817  0.02243071], f_best = 1.885066533207059
# 265
# pop. radius: 0.5838723066343126
# x_best = [-0.08739959 -0.03946817  0.02243071], f_best = 1.885066533207059
# 266
# pop. radius: 0.5838723066343126
# x_best = [-0.08739959 -0.03946817  0.02243071], f_best = 1.885066533207059
# 267
# pop. radius: 0.5838723066343126
# x_best = [-0.08739959 -0.03946817  0.02243071], f_best = 1.885066533207059
# 268
# pop. radius: 0.5838723066343126
# x_best = [-0.08739959 -0.03946817  0.02243071], f_best = 1.885066533207059
# 269
# pop. radius: 0.5850714681707212
# x_best = [-0.08739959 -0.03946817  0.02243071], f_best = 1.885066533207059
# 270
# pop. radius: 0.5850714681707212
# x_best = [-0.08739959 -0.03946817  0.02243071], f_best = 1.885066533207059
# 271
# pop. radius: 0.5850714681707212
# x_best = [-0.08739959 -0.03946817  0.02243071], f_best = 1.885066533207059
# 272
# pop. radius: 0.5848142987212175
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 273
# pop. radius: 0.5660902163656464
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 274
# pop. radius: 0.5660902163656464
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 275
# pop. radius: 0.5660902163656464
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 276
# pop. radius: 0.5660902163656464
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 277
# pop. radius: 0.5660902163656464
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 278
# pop. radius: 0.5660902163656464
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 279
# pop. radius: 0.5660902163656464
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 280
# pop. radius: 0.5660690048877359
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 281
# pop. radius: 0.5737357405259628
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 282
# pop. radius: 0.5737357405259628
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 283
# pop. radius: 0.5737357405259628
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 284
# pop. radius: 0.5668816374033916
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 285
# pop. radius: 0.5668816374033916
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 286
# pop. radius: 0.5668816374033916
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 287
# pop. radius: 0.5657821293538303
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 288
# pop. radius: 0.5657821293538303
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 289
# pop. radius: 0.5657821293538303
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 290
# pop. radius: 0.5656226973498045
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 291
# pop. radius: 0.5656226973498045
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 292
# pop. radius: 0.5790855261100001
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 293
# pop. radius: 0.5790855261100001
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 294
# pop. radius: 0.5790855261100001
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 295
# pop. radius: 0.5801297230396251
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 296
# pop. radius: 0.5914151547707056
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 297
# pop. radius: 0.5914151547707056
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 298
# pop. radius: 0.5914151547707056
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 299
# pop. radius: 0.5914151547707056
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 300
# pop. radius: 0.5914151547707056
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 301
# pop. radius: 0.5914151547707056
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 302
# pop. radius: 0.5914151547707056
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 303
# pop. radius: 0.6010164130093224
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 304
# pop. radius: 0.6062446002865406
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 305
# pop. radius: 0.6062446002865406
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 306
# pop. radius: 0.6062446002865406
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 307
# pop. radius: 0.6062446002865406
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 308
# pop. radius: 0.6062446002865406
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 309
# pop. radius: 0.6062446002865406
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 310
# pop. radius: 0.6062446002865406
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 311
# pop. radius: 0.6062446002865406
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 312
# pop. radius: 0.6062446002865406
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 313
# pop. radius: 0.6062446002865406
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 314
# pop. radius: 0.6062446002865406
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 315
# pop. radius: 0.6044012313041888
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 316
# pop. radius: 0.6060010970722653
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 317
# pop. radius: 0.6060010970722653
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 318
# pop. radius: 0.6060010970722653
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 319
# pop. radius: 0.6089988477781093
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 320
# pop. radius: 0.6089988477781093
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 321
# pop. radius: 0.6066295500368365
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 322
# pop. radius: 0.6066295500368365
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 323
# pop. radius: 0.6066295500368365
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 324
# pop. radius: 0.6066295500368365
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 325
# pop. radius: 0.6066295500368365
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 326
# pop. radius: 0.6087799537406483
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 327
# pop. radius: 0.623646429528417
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 328
# pop. radius: 0.623646429528417
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 329
# pop. radius: 0.623646429528417
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 330
# pop. radius: 0.623646429528417
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 331
# pop. radius: 0.6238018138756066
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 332
# pop. radius: 0.629654496082461
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 333
# pop. radius: 0.629654496082461
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 334
# pop. radius: 0.629654496082461
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 335
# pop. radius: 0.629654496082461
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 336
# pop. radius: 0.629654496082461
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 337
# pop. radius: 0.629654496082461
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 338
# pop. radius: 0.629654496082461
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 339
# pop. radius: 0.629654496082461
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 340
# pop. radius: 0.6315347636260922
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 341
# pop. radius: 0.6315347636260922
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 342
# pop. radius: 0.6315347636260922
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 343
# pop. radius: 0.6290012557381857
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 344
# pop. radius: 0.6290012557381857
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 345
# pop. radius: 0.6290012557381857
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 346
# pop. radius: 0.6290012557381857
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 347
# pop. radius: 0.6529032352513472
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 348
# pop. radius: 0.6529032352513472
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 349
# pop. radius: 0.6529032352513472
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 350
# pop. radius: 0.6529032352513472
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 351
# pop. radius: 0.6529032352513472
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 352
# pop. radius: 0.6529032352513472
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 353
# pop. radius: 0.6588926937935907
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 354
# pop. radius: 0.6588926937935907
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 355
# pop. radius: 0.6588926937935907
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 356
# pop. radius: 0.6588926937935907
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 357
# pop. radius: 0.6588926937935907
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 358
# pop. radius: 0.5565378963809079
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 359
# pop. radius: 0.5334752375297452
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 360
# pop. radius: 0.5332063277713746
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 361
# pop. radius: 0.5332063277713746
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 362
# pop. radius: 0.5332063277713746
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 363
# pop. radius: 0.5276219824316181
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 364
# pop. radius: 0.5276219824316181
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 365
# pop. radius: 0.5276219824316181
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 366
# pop. radius: 0.5276219824316181
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 367
# pop. radius: 0.5245459968006492
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 368
# pop. radius: 0.5245459968006492
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 369
# pop. radius: 0.5245459968006492
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 370
# pop. radius: 0.5300009424330883
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 371
# pop. radius: 0.5300009424330883
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 372
# pop. radius: 0.5300009424330883
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 373
# pop. radius: 0.5300009424330883
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 374
# pop. radius: 0.5300009424330883
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 375
# pop. radius: 0.5300009424330883
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 376
# pop. radius: 0.5300009424330883
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 377
# pop. radius: 0.5301607932950949
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 378
# pop. radius: 0.5301607932950949
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 379
# pop. radius: 0.5301607932950949
# x_best = [-0.03252391  0.05761474 -0.02574813], f_best = 0.9918065354270524
# 380
# pop. radius: 0.5251366506413174
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 381
# pop. radius: 0.5251366506413174
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 382
# pop. radius: 0.5251366506413174
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 383
# pop. radius: 0.5108260224961084
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 384
# pop. radius: 0.5108260224961084
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 385
# pop. radius: 0.5108260224961084
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 386
# pop. radius: 0.5053862167778933
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 387
# pop. radius: 0.5053862167778933
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 388
# pop. radius: 0.5053862167778933
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 389
# pop. radius: 0.5073439048170727
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 390
# pop. radius: 0.5073439048170727
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 391
# pop. radius: 0.5073439048170727
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 392
# pop. radius: 0.5073439048170727
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 393
# pop. radius: 0.5073439048170727
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 394
# pop. radius: 0.5073439048170727
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 395
# pop. radius: 0.5073439048170727
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 396
# pop. radius: 0.5073439048170727
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 397
# pop. radius: 0.4948649970719682
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 398
# pop. radius: 0.5082066912594585
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 399
# pop. radius: 0.5082066912594585
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 400
# pop. radius: 0.5082066912594585
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 401
# pop. radius: 0.5082066912594585
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 402
# pop. radius: 0.5050771118801737
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 403
# pop. radius: 0.5050771118801737
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 404
# pop. radius: 0.5139322462025768
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 405
# pop. radius: 0.5139322462025768
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 406
# pop. radius: 0.5141008035270911
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 407
# pop. radius: 0.5141008035270911
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 408
# pop. radius: 0.5191432028663843
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 409
# pop. radius: 0.5191432028663843
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 410
# pop. radius: 0.5191432028663843
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 411
# pop. radius: 0.5191432028663843
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 412
# pop. radius: 0.5191432028663843
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 413
# pop. radius: 0.4185952595959287
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 414
# pop. radius: 0.4185952595959287
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 415
# pop. radius: 0.4185952595959287
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 416
# pop. radius: 0.4185952595959287
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 417
# pop. radius: 0.3689359836296848
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 418
# pop. radius: 0.36816190486276273
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 419
# pop. radius: 0.36816190486276273
# x_best = [0.02736219 0.04328604 0.0199002 ], f_best = 0.5960847102430691
# 420
# pop. radius: 0.3569751179951319
# ...
# 864
# pop. radius: 0.18588445362220057
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 865
# pop. radius: 0.18562188422269066
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 866
# pop. radius: 0.1856220178346235
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 867
# pop. radius: 0.18567635688444636
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 868
# pop. radius: 0.1858296292497284
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 869
# pop. radius: 0.18576378141472866
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 870
# pop. radius: 0.18576378141472866
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 871
# pop. radius: 0.18566874278032194
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 872
# pop. radius: 0.1858387804749227
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 873
# pop. radius: 0.1858387804749227
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 874
# pop. radius: 0.18562219528579338
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 875
# pop. radius: 0.18562219528579338
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 876
# pop. radius: 0.18565394883580302
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 877
# pop. radius: 0.18565394883580302
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 878
# pop. radius: 0.18565394883580302
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 879
# pop. radius: 0.18565389586561257
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 880
# pop. radius: 0.18558565512930655
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 881
# pop. radius: 0.18564540264622648
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 882
# pop. radius: 0.1856453360906083
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 883
# pop. radius: 0.18564445387575343
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 884
# pop. radius: 0.18564445387575343
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 885
# pop. radius: 0.18564445387575343
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 886
# pop. radius: 0.18570285856294
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 887
# pop. radius: 0.1855555183609697
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 888
# pop. radius: 0.185555537387496
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 889
# pop. radius: 0.185555537387496
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 890
# pop. radius: 0.18555551322821923
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 891
# pop. radius: 0.005148895082981914
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 892
# pop. radius: 0.005115547927755808
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 893
# pop. radius: 0.005223934230759971
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 894
# pop. radius: 0.005223934230759971
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 895
# pop. radius: 0.005213991386984123
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 896
# pop. radius: 0.005246553930775542
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 897
# pop. radius: 0.0052426081650443134
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 898
# pop. radius: 0.004321740978167474
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 899
# pop. radius: 0.004305249458180885
# x_best = [ 0.00182782  0.0033497  -0.00343261], f_best = 0.005226305198370085
# 900
# pop. radius: 0.004348526216603782
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 901
# pop. radius: 0.0040759033432422355
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 902
# pop. radius: 0.0040759033432422355
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 903
# pop. radius: 0.004183563865582446
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 904
# pop. radius: 0.004187687392301749
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 905
# pop. radius: 0.004254658429040929
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 906
# pop. radius: 0.004226988868497603
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 907
# pop. radius: 0.004282072750251846
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 908
# pop. radius: 0.0042869581485561045
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 909
# pop. radius: 0.0042869581485561045
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 910
# pop. radius: 0.0042869581485561045
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 911
# pop. radius: 0.004360142352620931
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 912
# pop. radius: 0.004306082957006005
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 913
# pop. radius: 0.004257452234140692
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 914
# pop. radius: 0.004216237489009013
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 915
# pop. radius: 0.004220574123536358
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 916
# pop. radius: 0.0042902009742479584
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 917
# pop. radius: 0.0037593423598914913
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 918
# pop. radius: 0.003667713954508655
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 919
# pop. radius: 0.0037069020271788974
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 920
# pop. radius: 0.0037069020271788974
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 921
# pop. radius: 0.003787976353657355
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 922
# pop. radius: 0.003677262844025962
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 923
# pop. radius: 0.0036605471787178475
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 924
# pop. radius: 0.002888240942219395
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 925
# pop. radius: 0.0028701526562556526
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 926
# pop. radius: 0.002951602043179714
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 927
# pop. radius: 0.0029656176844507767
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 928
# pop. radius: 0.002990101498110402
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 929
# pop. radius: 0.0029606326549715626
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 930
# pop. radius: 0.002946270466668343
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 931
# pop. radius: 0.0029621019532571928
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 932
# pop. radius: 0.0029581053644139365
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 933
# pop. radius: 0.0029581053644139365
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 934
# pop. radius: 0.0029047536323035476
# x_best = [0.00174818 0.00011627 0.00199734], f_best = 0.001400437073499461
# 935
# pop. radius: 0.002896098639792525
# x_best = [ 0.00027972  0.00107424 -0.00204179], f_best = 0.0010715297892396336
# 936
# pop. radius: 0.0030371910239959036
# x_best = [ 0.00027972  0.00107424 -0.00204179], f_best = 0.0010715297892396336
# 937
# pop. radius: 0.0030371910239959036
# x_best = [ 0.00027972  0.00107424 -0.00204179], f_best = 0.0010715297892396336
# 938
# pop. radius: 0.003034006857942944
# x_best = [ 0.00027972  0.00107424 -0.00204179], f_best = 0.0010715297892396336
# 939
# pop. radius: 0.0030241270772181695
# x_best = [ 0.00027972  0.00107424 -0.00204179], f_best = 0.0010715297892396336
# 940
# pop. radius: 0.002982048283753323
# x_best = [ 0.00027972  0.00107424 -0.00204179], f_best = 0.0010715297892396336
# 941
# pop. radius: 0.002972267216487384
# x_best = [ 0.00027972  0.00107424 -0.00204179], f_best = 0.0010715297892396336
# 942
# pop. radius: 0.0029984799082121752
# x_best = [ 0.00027972  0.00107424 -0.00204179], f_best = 0.0010715297892396336
# 943
# pop. radius: 0.0030078635393314184
# x_best = [ 0.00027972  0.00107424 -0.00204179], f_best = 0.0010715297892396336
# 944
# pop. radius: 0.0030078635393314184
# x_best = [ 0.00027972  0.00107424 -0.00204179], f_best = 0.0010715297892396336
# 945
# pop. radius: 0.0030006890752689234
# x_best = [ 0.00027972  0.00107424 -0.00204179], f_best = 0.0010715297892396336
# 946
# pop. radius: 0.0030040795836137994
# x_best = [ 0.00027972  0.00107424 -0.00204179], f_best = 0.0010715297892396336
# 947
# pop. radius: 0.0029812026120740963
# x_best = [ 0.00027972  0.00107424 -0.00204179], f_best = 0.0010715297892396336
# 948
# pop. radius: 0.002360843596566378
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 949
# pop. radius: 0.002360843596566378
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 950
# pop. radius: 0.0024074130395658013
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 951
# pop. radius: 0.0023887071478017005
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 952
# pop. radius: 0.0023678730496621194
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 953
# pop. radius: 0.002133084369898388
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 954
# pop. radius: 0.002068916353769035
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 955
# pop. radius: 0.0017171996413377253
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 956
# pop. radius: 0.0017033894591814804
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 957
# pop. radius: 0.0017239014986002168
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 958
# pop. radius: 0.0016715019049780764
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 959
# pop. radius: 0.0016715019049780764
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 960
# pop. radius: 0.001692751103121695
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 961
# pop. radius: 0.0014924447225281418
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 962
# pop. radius: 0.001510727632423775
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 963
# pop. radius: 0.001508817525504232
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 964
# pop. radius: 0.0015030637873702558
# x_best = [0.00033463 0.00045106 0.00107282], f_best = 0.0002909187835911098
# 965
# pop. radius: 0.0015299602702448115
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 966
# pop. radius: 0.0015299602702448115
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 967
# pop. radius: 0.0015001968974142552
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 968
# pop. radius: 0.0014966865273130254
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 969
# pop. radius: 0.001509667808044123
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 970
# pop. radius: 0.0015222541955771344
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 971
# pop. radius: 0.0015222541955771344
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 972
# pop. radius: 0.0014201953989233396
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 973
# pop. radius: 0.0014400819919603452
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 974
# pop. radius: 0.0014438716585049812
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 975
# pop. radius: 0.0014419248311091086
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 976
# pop. radius: 0.0014174850300904974
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 977
# pop. radius: 0.0014194997606891625
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 978
# pop. radius: 0.0014194997606891625
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 979
# pop. radius: 0.0013940121616061835
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 980
# pop. radius: 0.0013687134336029035
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 981
# pop. radius: 0.0013687134336029035
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 982
# pop. radius: 0.0013674341543708796
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 983
# pop. radius: 0.0013629049366892469
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 984
# pop. radius: 0.0013785910933400201
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 985
# pop. radius: 0.0010784726839168268
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 986
# pop. radius: 0.0010784726839168268
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 987
# pop. radius: 0.0010784726839168268
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 988
# pop. radius: 0.001100031923644779
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 989
# pop. radius: 0.001049729015035705
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 990
# pop. radius: 0.0010420944726167733
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 991
# pop. radius: 0.0010337497848862496
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 992
# pop. radius: 0.0010337497848862496
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 993
# pop. radius: 0.0010337497848862496
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 994
# pop. radius: 0.001029595481337906
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 995
# pop. radius: 0.0010333090880569513
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 996
# pop. radius: 0.0010486905849747823
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 997
# pop. radius: 0.0010345465386803136
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 998
# pop. radius: 0.0010250995174895601
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 999
# pop. radius: 0.001022971744667813
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# 1000
# pop. radius: 0.001022971744667813
# x_best = [ 0.00066024 -0.00014633  0.00038374], f_best = 0.00011994526889935742
# x_best = [ 1.28953480e-04 -2.85805227e-05  7.49489323e-05], f_best = 0.00011994526889935742

# %%
hist_values = met.historical

plt.figure()
plt.plot(hist_values['fitness'], lw=2)
plt.xlabel('Iteration'), plt.ylabel('Fitness')
plt.tight_layout()
plt.show()
# plt.savefig('ExFitness.svg')

# %%
plt.figure()
plt.plot(hist_values['centroid'])
plt.xlabel(r'Iteration'), plt.ylabel(r'Centroid')
plt.legend([r'$x_1$', r'$x_2$', r'$x_3$'], frameon=False)
plt.tight_layout()
plt.show()
# plt.savefig('ExCentroid.svg')

# %%
plt.figure()
plt.plot(hist_values['radius'])
plt.xlabel(r'Iteration'), plt.ylabel(r'Radius')
plt.tight_layout()
plt.show()
# plt.savefig('E|xRadius.svg')

# %% [markdown]
# Let us try another metaheuristic

# %%
# This the minimisation problem to solve
fun = bf.Griewank(6)
prob = fun.get_formatted_problem()
fun.plot()

# %%
# This will be the metaheuristic
heu_seq = [
    ('random_search', {'scale': 1.0, 'distribution': 'uniform'}, 'greedy'),
    ('spiral_dynamic', {'radius': 0.9, 'angle': 33.5, 'sigma': 0.1}, 'all'),
    ('gravitational_search', {'gravity': 0.5, 'alpha': 0.2}, 'metropolis')
    ]
met = mh.Metaheuristic(prob, heur, num_iterations=500, num_agents=100)
met.verbose = False
met.run()
print('x_best = {}, f_best = {}'.format(*met.get_solution()))
# Out:
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 500, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# x_best = [-0.13275211  0.12926869  0.09522043  0.06260189 -0.07271984 -0.22166151], f_best = 0.778060221833422

# %%
hist_values = met.historical

fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].plot(hist_values['fitness'], lw=2)
axs[0].set_xlabel('Iteration'), axs[0].set_ylabel('Fitness')

axs[1].plot(hist_values['position'])
axs[1].set_xlabel(r'Iteration'), axs[1].set_ylabel(r'Position')
axs[1].legend([f"$x_{ii+1}$" for ii in range(6)], frameon=False)

plt.show()

# %%
# Initialise the fitness register
fitness = []
# Run the metaheuristic with the same problem 30 times
for rep in range(30):
    met = mh.Metaheuristic(prob, heur, num_iterations=50, num_agents=100)
    met.reset_historicals()
    met.verbose = False
    met.run()
    print('rep = {}, x_best = {}, f_best = {}'.format(rep+1, *met.get_solution()))
    
    fitness.append(met.historical['fitness'])
# Out:
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 1, x_best = [ 0.29423899 -0.14560021  0.07568901  0.00552327  0.08259787  0.11950736], f_best = 1.3245917028434482
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 2, x_best = [0.20940291 0.57503829 0.14233828 0.06467577 0.22992894 0.15911539], f_best = 2.303627373200059
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 3, x_best = [-0.18556627  0.09686501 -0.17524894 -0.28168633  0.13299326 -0.38199066], f_best = 1.7629010500135422
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 4, x_best = [-0.19049526  0.0084231  -0.3882484  -0.381408   -0.05875364 -0.16874293], f_best = 1.3948322182445632
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 5, x_best = [-0.30090756  0.22998165 -0.1554005  -0.15811434  0.03592016  0.07403749], f_best = 1.4987353043308378
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 6, x_best = [ 0.20587965  0.09948705  0.22469612  0.18227333 -0.09538691  0.19511545], f_best = 1.452787039968923
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 7, x_best = [-0.55868844 -0.05379055  0.03209831 -0.08484249  0.11465904  0.28569445], f_best = 2.0644112433206363
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 8, x_best = [-0.1344557   0.35084625 -0.05164904 -0.14542639 -0.18928725 -0.44526799], f_best = 1.8501620630912643
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 9, x_best = [-0.20928235  0.15000979  0.12512871 -0.27516702 -0.1275257   0.28997337], f_best = 1.620027146543395
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 10, x_best = [ 0.30828503 -0.00058785  0.22464672 -0.08789675 -0.19732259 -0.22418681], f_best = 1.7958701918721813
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 11, x_best = [-0.03717422 -0.53621743 -0.04666031 -0.18707757 -0.13452191  0.3787642 ], f_best = 1.5299758835976505
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 12, x_best = [ 0.06866837  0.02178948  0.07661011 -0.13814571  0.45027702 -0.06791084], f_best = 1.5922486146917705
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 13, x_best = [ 0.16780596 -0.10124268  0.10651444 -0.01021606 -0.19501532 -0.01058333], f_best = 1.0367820676054618
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 14, x_best = [-0.05370882 -0.1773954  -0.19618195  0.26532851  0.20255723 -0.08440634], f_best = 1.3430307809159625
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 15, x_best = [-0.34259087  0.04980903  0.17195574 -0.02054429 -0.30199556  0.25380318], f_best = 1.6229933630044995
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 16, x_best = [-0.38389288 -0.34414679  0.02509277 -0.2653778   0.08788306 -0.27533244], f_best = 2.059540729341994
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 17, x_best = [-0.15942346 -0.11018371 -0.02135526 -0.37497881 -0.06691518  0.34517505], f_best = 1.7547074322196587
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 18, x_best = [-0.16847336 -0.01127129 -0.11709477  0.11124927 -0.40507411  0.18873143], f_best = 1.6572588064747795
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 19, x_best = [-0.08173346 -0.41289681  0.12648967 -0.24503018 -0.18216454 -0.04709735], f_best = 1.7121190683569416
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 20, x_best = [ 0.3365842  -0.12387816 -0.21901023 -0.10730152  0.19604675 -0.11032745], f_best = 1.5482728362398603
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 21, x_best = [-0.1642969   0.3038586   0.03921483 -0.33189028 -0.13091815  0.03067027], f_best = 1.547100635981388
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 22, x_best = [-0.35281782 -0.12651798 -0.0023288   0.26047879  0.26410053 -0.29987374], f_best = 1.512163443514059
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 23, x_best = [ 0.2040368   0.04163564 -0.01766501  0.29157526 -0.27999915 -0.01933795], f_best = 1.5160925387208684
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 24, x_best = [-0.0670909  -0.18198159  0.13074431  0.23410773 -0.37458114 -0.05933628], f_best = 1.5688977454491744
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 25, x_best = [ 0.16297291 -0.34971488  0.15699715  0.34845714 -0.19265661 -0.38085763], f_best = 2.122757377047696
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 26, x_best = [-0.06115619 -0.03850922 -0.03416823  0.09976202 -0.24145359 -0.03700185], f_best = 1.1911620828023977
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 27, x_best = [-0.2042063   0.22547574 -0.34354047 -0.06968416 -0.08224058 -0.03725207], f_best = 1.558910669123943
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 28, x_best = [-0.58080224  0.10084249  0.08721715 -0.00236057  0.19273107  0.03049922], f_best = 1.9847852124559977
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 29, x_best = [-0.30867543  0.0214538  -0.10944137 -0.29921348  0.08842179  0.15964232], f_best = 1.553888006398824
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 100, Num_iterations: 50, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 6 ---
# --- LOG: Número de agentes: 100 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# rep = 30, x_best = [-0.16776926 -0.04035332 -0.29543423  0.35334172  0.19406568 -0.27935103], f_best = 1.8827920369462752

# %%
fitness
# Out:
# [[array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(2.04723518),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.72110677),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.55440048),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917),
#   array(1.3245917)],
#  [array(2.42304551),
#   array(2.42304551),
#   array(2.42304551),
#   array(2.42304551),
#   array(2.42304551),
#   array(2.42304551),
#   array(2.42304551),
#   array(2.42304551),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737),
#   array(2.30362737)],
#  [array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(3.13426047),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105),
#   array(1.76290105)],
#  [array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39612983),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222),
#   array(1.39483222)],
#  [array(2.43501798),
#   array(2.43501798),
#   array(2.43501798),
#   array(2.43501798),
#   array(2.43501798),
#   array(2.43501798),
#   array(2.43501798),
#   array(2.43501798),
#   array(2.43501798),
#   array(2.43501798),
#   array(2.43501798),
#   array(2.43501798),
#   array(2.43501798),
#   array(2.43501798),
#   array(2.43501798),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353),
#   array(1.4987353)],
#  [array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(2.54859985),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.93625882),
#   array(1.83605455),
#   array(1.83605455),
#   array(1.83605455),
#   array(1.45278704),
#   array(1.45278704),
#   array(1.45278704),
#   array(1.45278704),
#   array(1.45278704),
#   array(1.45278704),
#   array(1.45278704),
#   array(1.45278704),
#   array(1.45278704),
#   array(1.45278704),
#   array(1.45278704),
#   array(1.45278704),
#   array(1.45278704),
#   array(1.45278704),
#   array(1.45278704)],
#  [array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.32408884),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124),
#   array(2.06441124)],
#  [array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(2.04864734),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206),
#   array(1.85016206)],
#  [array(2.29746042),
#   array(2.29746042),
#   array(2.29746042),
#   array(2.29746042),
#   array(2.29746042),
#   array(2.29746042),
#   array(2.29746042),
#   array(2.21318166),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(2.01324862),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715),
#   array(1.62002715)],
#  [array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(2.28120643),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019),
#   array(1.79587019)],
#  [array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.57169839),
#   array(1.52997588),
#   array(1.52997588),
#   array(1.52997588),
#   array(1.52997588),
#   array(1.52997588)],
#  [array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(2.24434347),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861),
#   array(1.59224861)],
#  [array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207),
#   array(1.03678207)],
#  [array(1.39993337),
#   array(1.39993337),
#   array(1.39993337),
#   array(1.39993337),
#   array(1.39993337),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078),
#   array(1.34303078)],
#  [array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336),
#   array(1.62299336)],
#  [array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.2179479),
#   array(2.12923196),
#   array(2.12923196),
#   array(2.12923196),
#   array(2.12923196),
#   array(2.12923196),
#   array(2.12923196),
#   array(2.12923196),
#   array(2.12923196),
#   array(2.12923196),
#   array(2.12923196),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073),
#   array(2.05954073)],
#  [array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(2.21424055),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743),
#   array(1.75470743)],
#  [array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881),
#   array(1.65725881)],
#  [array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(2.02392859),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907),
#   array(1.71211907)],
#  [array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284),
#   array(1.54827284)],
#  [array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.2878586),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.20997548),
#   array(2.13530878),
#   array(2.13530878),
#   array(2.13530878),
#   array(2.13530878),
#   array(2.13530878),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064),
#   array(1.54710064)],
#  [array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.76820126),
#   array(1.5658325),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344),
#   array(1.51216344)],
#  [array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(2.22006546),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.8963102),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254),
#   array(1.51609254)],
#  [array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.58250722),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775),
#   array(1.56889775)],
#  [array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.35815603),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.3088769),
#   array(2.14710888),
#   array(2.14710888),
#   array(2.14710888),
#   array(2.14710888),
#   array(2.14710888),
#   array(2.14710888),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738),
#   array(2.12275738)],
#  [array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208),
#   array(1.19116208)],
#  [array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067),
#   array(1.55891067)],
#  [array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(2.53208714),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521),
#   array(1.98478521)],
#  [array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.73104132),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.71439244),
#   array(1.55388801),
#   array(1.55388801),
#   array(1.55388801)],
#  [array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(2.02057829),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.91619178),
#   array(1.88279204),
#   array(1.88279204),
#   array(1.88279204),
#   array(1.88279204),
#   array(1.88279204),
#   array(1.88279204),
#   array(1.88279204),
#   array(1.88279204),
#   array(1.88279204),
#   array(1.88279204),
#   array(1.88279204),
#   array(1.88279204)]]

# %%
fitness_array = np.array(fitness).T
final_fitness = np.array([x[-1] for x in fitness_array.T])
best_fitness = np.min(fitness_array)
initial_fitness = max([x[0] for x in fitness_array])

# Now plot the fitness values
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12, 4), sharey='row', gridspec_kw={'width_ratios': [0.8, 0.2]})
axs[0].plot(fitness_array, 'grey', alpha=0.3)

axs[0].plot(np.min(fitness_array, axis=1), 'g', lw=2, label='Best')
axs[0].plot(np.max(fitness_array, axis=1), 'k', lw=2, label='Worst')
axs[0].plot(np.mean(fitness_array, axis=1), 'b', lw=2, label='Mean')
axs[0].plot(np.median(fitness_array, axis=1), 'r', lw=2, label='Median')

axs[0].set_ylabel(r'Fitness')
axs[0].set_xlabel(r'Iteration')
axs[0].set_ylim([best_fitness, initial_fitness])

# Violin plot
axs[1].violinplot(final_fitness, showmeans=True, showmedians=True)
axs[1].set_xlabel(r'Data')

axs[0].legend(frameon=False)

axs[0].set_yscale('log')
axs[1].set_yscale('log')
axs[0].set_xscale('log')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Module of Hyper-Heuristics (customhys.hyperheuristic)
# This section is dedicated to the use of the module to implement a hyper-heuristic for finding the most suitable metaheuristic for a given problem.

# %%
parameters = dict(
    cardinality=3,  # Max. numb. of SOs in MHs, lvl:1
    cardinality_min=1,  # Min. numb. of SOs in MHs, lvl:1
    num_iterations=100,  # Iterations an MH performs, lvl:1
    num_agents=30,  # Agents in population,     lvl:1
    as_mh=True,  # HH sequence as a MH?,     lvl:2
    num_replicas=30,  # Replicas per each MH,     lvl:2
    num_steps=50,  # Trials per HH step,       lvl:2
    stagnation_percentage=0.37,  # Stagnation percentage,    lvl:2
    max_temperature=100,  # Initial temperature (SA), lvl:2
    min_temperature=1e-6,  # Min temperature (SA),     lvl:2
    cooling_rate=1e-3,  # Cooling rate (SA),        lvl:2
    temperature_scheme='fast',  # Temperature updating (SA),lvl:2
    acceptance_scheme='exponential',  # Acceptance mode,          lvl:2
    allow_weight_matrix=True,  # Weight matrix,            lvl:2
    trial_overflow=False,  # Trial overflow policy,    lvl:2
    learnt_dataset=None,  # If it is a learnt dataset related with the heuristic space
    repeat_operators=True,  # Allow repeating SOs inSeq,lvl:2
    verbose=True,  # Verbose process,          lvl:2
    learning_portion=0.37,  # Percent of seqs to learn  lvl:2
    solver='static')  # Indicate which solver use lvl:1

# %%
from customhys import hyperheuristic as hh

dime = 5
fun = bf.Griewank(dime)

cate = fun.get_features()
prob = fun.get_formatted_problem()
hyp = hh.Hyperheuristic(heuristic_space="default.txt",
                        problem=prob, parameters=parameters, file_label='Griewank-5D-Exp2')

best_sol, best_perf, hist_curr, hist_best = hyp.solve()
# Out:
# --- LOG: Iniciando _solve_static ---
# --- LOG: Gerando solução inicial ---
# --- LOG: Entrando em _obtain_candidate_solution ---
# Parâmetro recebido sol: None
# Parâmetro action: None
# Parâmetro operators_weights: None
# Parâmetro top: None
# --- LOG: Criando solução inicial ---
# --- LOG: encoded_neighbour gerado: [6] ---
# --- LOG: Solução inicial gerada: [6] ---
# --- LOG: Avaliando solução inicial ---
# --- LOG: Iniciando evaluate_candidate_solution ---
# --- LOG: encoded_sequence recebido ---
# Tipo: <class 'list'> | Conteúdo: [6]
# --- LOG: encoded_sequence convertido para operadores ---
# [('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')]
# --- LOG: search_operators validado ---
# [('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')]
# --- LOG: Iniciando execuções da Metaheuristic ---
# --- LOG: Rodada 1/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 2/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 3/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 4/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 5/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 6/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 7/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 8/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 9/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 10/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 11/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 12/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 13/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 14/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 15/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 16/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 17/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 18/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 19/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 20/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 21/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 22/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 23/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 24/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 25/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 26/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 27/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 28/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 29/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 30/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('differential_mutation', {'expression': 'rand', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Avaliação finalizada ---
# --- LOG: fitness_stats ---
# {'nob': 30, 'Min': 0.430480082652296, 'Max': 1.355291855286734, 'Avg': 0.8631162634676743, 'Std': 0.24544154108025576, 'Skw': 0.021402849372819385, 'Kur': -0.960290929036784, 'IQR': 0.4199225279346859, 'Med': 0.8477577190614787, 'MAD': 0.2188744516483866}
# --- LOG: Performance inicial: 1.2676802469961646 ---
# Griewank-5D-Exp2 :: Step:    0, Temp: 1.00e+02, Perf: 1.27e+00 [Initial]
# --- LOG: Passo 1 - Gerando vizinho ---
# --- LOG: Entrando em _obtain_candidate_solution ---
# Parâmetro recebido sol: [6]
# Parâmetro action: Shift
# Parâmetro operators_weights: None
# Parâmetro top: None
# --- LOG: sol é uma lista ou ndarray, aplicando perturbação ---
# --- LOG: Ação escolhida: Shift ---
# --- LOG: encoded_neighbour gerado: [188] ---
# --- LOG: Vizinho gerado: [188] ---
# --- LOG: Avaliando candidato ---
# --- LOG: Iniciando evaluate_candidate_solution ---
# --- LOG: encoded_sequence recebido ---
# Tipo: <class 'list'> | Conteúdo: [188]
# --- LOG: encoded_sequence convertido para operadores ---
# [('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')]
# --- LOG: search_operators validado ---
# [('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')]
# --- LOG: Iniciando execuções da Metaheuristic ---
# --- LOG: Rodada 1/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 2/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 3/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 4/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 5/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 6/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 7/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 8/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 9/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 10/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 11/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('swarm_dynamic', {'factor': 0.7, 'self_conf': 2.54, 'swarm_conf': 2.56, 'version': 'inertial', 'distribution': 'gaussian'}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 12/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# ...
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 21/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 3) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 3
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 22/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 3) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 3
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 23/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 3) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 3
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 24/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 3) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 3
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 25/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 3) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 3
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 26/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 3) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 3
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 27/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 3) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 3
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 28/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 3) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 3
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 29/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 3) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 3
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 30/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 3) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 3
# Operador 0: ('differential_mutation', {'expression': 'best', 'num_rands': 1, 'factor': 1.0}, 'greedy')
# Operador 1: ('random_flight', {'scale': 1.0, 'distribution': 'uniform'}, 'probabilistic')
# Operador 2: ('firefly_dynamic', {'distribution': 'gaussian', 'alpha': 1.0, 'beta': 1.0, 'gamma': 100.0}, 'metropolis')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Avaliação finalizada ---
# --- LOG: fitness_stats ---
# {'nob': 30, 'Min': 0.8415448997453923, 'Max': 1.6446152423403664, 'Avg': 1.224989661225543, 'Std': 0.2301633526988157, 'Skw': 0.03705701704910358, 'Kur': -0.8848877422751542, 'IQR': 0.34340284696587275, 'Med': 1.2429789544772425, 'MAD': 0.18564335486490968}
# --- LOG: Performance do candidato: 1.5863818014431152 ---
# Griewank-5D-Exp2 :: Step:   28, Temp: 3.57e+00, Perf: 1.59e+00
# , [Delta: -1.12e-01, ArgProb: 1.38e-02, Prob: 1.00] --- LOG: Aceitando nova solução ---
#
# --- LOG: Melhor solução encontrada --> Perf: 0.937736513685815, Sol: [94] ---

# %%
# print("Performance: ", best_perf)
# print(best_sol)

# %%
from customhys import tools as tl
full_data = tl.merge_json("./data_files/raw/Griewank-5D-Exp2")
#full_data = tl.read_json("./Exp1.json")
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 25.37it/s]
# Merged file saved: ./data_files/raw/Griewank-5D-Exp2.json

# %%
full_data = tl.read_json("./data_files/raw/Griewank-5D-Exp2.json")

# %%
tl.printmsk(full_data)
# Out:
# |-- {list: 3}
# |  |-- 0 = {dict: 5}
# |  |  |-- file_name = {str}
# |  |  |-- step = {int}
# |  |  |-- encoded_solution = {list: 1}
# |  |  |  |-- 0 = {int}
# :  :  :  :
# |  |  |-- performance = {float}
# |  |  |-- details = {dict: 4}
# |  |  |  |-- historical = {list: 30}
# |  |  |  |  |-- 0 = {dict: 4}
# |  |  |  |  |  |-- fitness = {list: 101}
# |  |  |  |  |  |  |-- 0 = {float}
# :  :  :  :  :  :  :
# |  |  |  |  |  |-- position = {list: 101}
# |  |  |  |  |  |  |-- 0 = {list: 5}
# |  |  |  |  |  |  |  |-- 0 = {float}
# :  :  :  :  :  :  :  :
# :  :  :  :  :  :  :
# |  |  |  |  |  |-- centroid = {list: 101}
# |  |  |  |  |  |  |-- 0 = {list: 5}
# |  |  |  |  |  |  |  |-- 0 = {float}
# :  :  :  :  :  :  :  :
# :  :  :  :  :  :  :
# |  |  |  |  |  |-- radius = {list: 101}
# |  |  |  |  |  |  |-- 0 = {float}
# :  :  :  :  :  :  :
# :  :  :  :  :
# |  |  |  |-- fitness = {list: 30}
# |  |  |  |  |-- 0 = {float}
# :  :  :  :  :
# |  |  |  |-- positions = {list: 30}
# |  |  |  |  |-- 0 = {list: 5}
# |  |  |  |  |  |-- 0 = {float}
# :  :  :  :  :  :
# :  :  :  :  :
# |  |  |  |-- statistics = {dict: 10}
# |  |  |  |  |-- nob = {int}
# |  |  |  |  |-- Min = {float}
# |  |  |  |  |-- Max = {float}
# |  |  |  |  |-- Avg = {float}
# |  |  |  |  |-- Std = {float}
# |  |  |  |  |-- Skw = {float}
# |  |  |  |  |-- Kur = {float}
# |  |  |  |  |-- IQR = {float}
# |  |  |  |  |-- Med = {float}
# |  |  |  |  |-- MAD = {float}
# :  :

# %%
num_steps = len(full_data)
# print(full_data['details'])
# historical_fitness = [[x[['fitness']][-1] for x in historical] for historical in full_data['details']]
historical_fitness = [x['details']['fitness'] for x in full_data]
performances = [x['performance'] for x in full_data]
steps = [x['step'] for x in full_data]

# %%
from customhys import visualisation as vis
vis.show_performance_overview(steps, historical_fitness, performances)

# %%
initial_fitness = max([max([x['fitness'][0] for x in fitness_rep['details']['historical']]) for fitness_rep in full_data])
best_fitness = np.min(historical_fitness)

for ii, step in enumerate(steps):
    historical_data = full_data[ii]['details']['historical']
    all_fitness_repetitions = np.array([fitness_rep['fitness'] for fitness_rep in historical_data]).T

    fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12, 4), sharey='row', gridspec_kw={'width_ratios': [0.8, 0.2]})
    axs[0].plot(all_fitness_repetitions, 'g', alpha=0.75)
    axs[0].set_ylabel(r'Fitness')
    axs[0].set_xlabel(r'Iteration')
    axs[0].set_ylim([best_fitness, initial_fitness])

    axs[1].boxplot(historical_fitness[ii])
    axs[1].set_xlabel(r'Data')

    plt.suptitle(r'MH$^{' + '{}'.format(len(full_data[ii]['encoded_solution'])) + '} = \\{' +
              '}, '.join(['h_{' + str(x) for x in full_data[ii]['encoded_solution']]) + '}\\}$')
    plt.tight_layout()
    plt.show()
    # plt.savefig('hh_raw_fitness_s{}.eps'.format(data['step'][ii]))

# %%
met = mh.Metaheuristic(prob, heur, num_iterations=1000)
met.verbose = True
met.run()
print('x_best = {}, f_best = {}'.format(*met.get_solution()))
# Out:
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 1000, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
#
# Search operators to employ:
# differential_mutation(expression='current-to-best',num_rands=2,factor=1.0) with greedy
# differential_crossover(crossover_rate=0.2,version='binomial') with greedy
# --------------------------------------------------
# 1
# pop. radius: 1.5596829552762876
# x_best = [ 21.84478815  44.56023767  13.34303426 -20.07516937 -39.48054062], f_best = 2.1061494514530823
# 2
# pop. radius: 1.5711589861925932
# x_best = [ 21.84478815  44.56023767  13.34303426 -20.07516937 -39.48054062], f_best = 2.1061494514530823
# 3
# pop. radius: 1.5711589861925932
# x_best = [ 21.84478815  44.56023767  13.34303426 -20.07516937 -39.48054062], f_best = 2.1061494514530823
# 4
# pop. radius: 1.5798478544196357
# x_best = [ 21.84478815  44.56023767  13.34303426 -20.07516937 -39.48054062], f_best = 2.1061494514530823
# 5
# pop. radius: 1.5798478544196357
# x_best = [ 21.84478815  44.56023767  13.34303426 -20.07516937 -39.48054062], f_best = 2.1061494514530823
# 6
# pop. radius: 1.5047001465453393
# x_best = [ 21.84478815  44.56023767  13.34303426 -20.07516937 -39.48054062], f_best = 2.1061494514530823
# 7
# pop. radius: 1.5228398412768278
# x_best = [ 21.84478815  44.56023767  13.34303426 -20.07516937 -39.48054062], f_best = 2.1061494514530823
# 8
# pop. radius: 1.5347680432322397
# x_best = [ 21.84478815  44.56023767  13.34303426 -20.07516937 -39.48054062], f_best = 2.1061494514530823
# 9
# pop. radius: 1.4812753527925584
# x_best = [ 21.84478815  44.56023767  13.34303426 -20.07516937 -39.48054062], f_best = 2.1061494514530823
# 10
# pop. radius: 1.4835760636043192
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 11
# pop. radius: 1.4827819384622523
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 12
# pop. radius: 1.4559202681739838
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 13
# pop. radius: 1.4362940621994529
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 14
# pop. radius: 1.4362940621994529
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 15
# pop. radius: 1.4362940621994529
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 16
# pop. radius: 1.424139905245443
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 17
# pop. radius: 1.424139905245443
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 18
# pop. radius: 1.424139905245443
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 19
# pop. radius: 1.4232019325127727
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 20
# pop. radius: 1.4232019325127727
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 21
# pop. radius: 1.4264750526135888
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 22
# pop. radius: 1.4264750526135888
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 23
# pop. radius: 1.411441841720257
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 24
# pop. radius: 1.411441841720257
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 25
# pop. radius: 1.4084612932802882
# x_best = [-3.99359321e+01 -4.86458763e+00  6.34984475e-03 -1.83151236e+01
#   3.87839984e+00], f_best = 1.399437079482696
# 26
# pop. radius: 1.4141533879885013
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 27
# pop. radius: 1.3826178160230826
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 28
# pop. radius: 1.3826178160230826
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 29
# pop. radius: 1.3826178160230826
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 30
# pop. radius: 1.3826178160230826
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 31
# pop. radius: 1.3428711086745275
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 32
# pop. radius: 1.3312519883544938
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 33
# pop. radius: 1.3312519883544938
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 34
# pop. radius: 1.3312519883544938
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 35
# pop. radius: 1.322982316263114
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 36
# pop. radius: 1.322982316263114
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 37
# pop. radius: 1.322982316263114
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 38
# pop. radius: 1.322982316263114
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 39
# pop. radius: 1.3173947682278655
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 40
# pop. radius: 1.3173947682278655
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 41
# pop. radius: 1.3308248772449796
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 42
# pop. radius: 1.3308248772449796
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 43
# pop. radius: 1.3228754873601198
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 44
# pop. radius: 1.3320151667127125
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 45
# pop. radius: 1.3320151667127125
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 46
# pop. radius: 1.3320151667127125
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 47
# pop. radius: 1.3220228741634101
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 48
# pop. radius: 1.3220228741634101
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 49
# pop. radius: 1.3220228741634101
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 50
# pop. radius: 1.3220228741634101
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 51
# pop. radius: 1.3076929164763924
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 52
# pop. radius: 1.3076929164763924
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 53
# pop. radius: 1.3064094861105602
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 54
# pop. radius: 1.3064094861105602
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 55
# pop. radius: 1.3026187624220957
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 56
# pop. radius: 1.3026187624220957
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 57
# pop. radius: 1.3026187624220957
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 58
# pop. radius: 1.3026187624220957
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 59
# pop. radius: 1.3026187624220957
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 60
# pop. radius: 1.3026187624220957
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 61
# pop. radius: 1.2638276469280447
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 62
# pop. radius: 1.2478788302266084
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 63
# pop. radius: 1.2478788302266084
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 64
# pop. radius: 1.2616415048546872
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 65
# pop. radius: 1.2616415048546872
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 66
# pop. radius: 1.2779856495968134
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 67
# pop. radius: 1.2539071298368265
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 68
# pop. radius: 1.2789712863886145
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 69
# pop. radius: 1.2789712863886145
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 70
# pop. radius: 1.270621979156021
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 71
# pop. radius: 1.243499518369908
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 72
# pop. radius: 1.2381895591044263
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 73
# pop. radius: 1.2381895591044263
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 74
# pop. radius: 1.2381895591044263
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 75
# pop. radius: 1.2381895591044263
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 76
# pop. radius: 1.2291482598302197
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 77
# pop. radius: 1.2291482598302197
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 78
# pop. radius: 1.2291482598302197
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 79
# pop. radius: 1.2291482598302197
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 80
# pop. radius: 1.2291482598302197
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 81
# pop. radius: 1.2223068565808666
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 82
# pop. radius: 1.2223068565808666
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 83
# pop. radius: 1.2251557830601294
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 84
# pop. radius: 1.2251557830601294
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 85
# pop. radius: 1.2251557830601294
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 86
# pop. radius: 1.2251557830601294
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 87
# pop. radius: 1.2251557830601294
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 88
# pop. radius: 1.2303724270603336
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 89
# pop. radius: 1.2303724270603336
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 90
# pop. radius: 1.2303724270603336
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 91
# pop. radius: 1.2303724270603336
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 92
# pop. radius: 1.23506210701095
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 93
# pop. radius: 1.23506210701095
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 94
# pop. radius: 1.23506210701095
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 95
# pop. radius: 1.23506210701095
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 96
# pop. radius: 1.23506210701095
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 97
# pop. radius: 1.23506210701095
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 98
# pop. radius: 1.2316365538772058
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 99
# pop. radius: 1.2316365538772058
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 100
# pop. radius: 1.2128902248913611
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 101
# pop. radius: 1.2128902248913611
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 102
# pop. radius: 1.2128902248913611
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 103
# pop. radius: 1.2128902248913611
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 104
# pop. radius: 1.2128902248913611
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 105
# pop. radius: 1.2128902248913611
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 106
# pop. radius: 1.2128902248913611
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 107
# pop. radius: 1.2128902248913611
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 108
# pop. radius: 1.1966837573711746
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 109
# pop. radius: 1.1966837573711746
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 110
# pop. radius: 1.2098967359005433
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 111
# pop. radius: 1.1821567646547175
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 112
# pop. radius: 1.1729536142672672
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 113
# pop. radius: 1.1729536142672672
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 114
# pop. radius: 1.1729536142672672
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 115
# pop. radius: 1.1729536142672672
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 116
# pop. radius: 1.1729536142672672
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 117
# pop. radius: 1.1729536142672672
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 118
# pop. radius: 1.1729536142672672
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 119
# pop. radius: 1.1729536142672672
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 120
# pop. radius: 1.1729536142672672
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 121
# pop. radius: 1.1729536142672672
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 122
# pop. radius: 1.1746861609502621
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 123
# pop. radius: 1.1746861609502621
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 124
# pop. radius: 1.1746861609502621
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 125
# pop. radius: 1.1756955240650617
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 126
# pop. radius: 1.1460031220358844
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 127
# pop. radius: 1.1067322967980382
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 128
# pop. radius: 1.1067322967980382
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 129
# pop. radius: 1.1067322967980382
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 130
# pop. radius: 1.1067322967980382
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 131
# pop. radius: 1.1067322967980382
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 132
# pop. radius: 1.1067322967980382
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 133
# pop. radius: 1.1067322967980382
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 134
# pop. radius: 1.1067322967980382
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 135
# pop. radius: 1.1067322967980382
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 136
# pop. radius: 1.1137899947143082
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 137
# pop. radius: 1.1129068551634185
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 138
# pop. radius: 1.1129068551634185
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 139
# pop. radius: 1.1031853471159956
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 140
# pop. radius: 1.1031853471159956
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 141
# pop. radius: 1.1031853471159956
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 142
# pop. radius: 1.1031853471159956
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 143
# pop. radius: 1.1031853471159956
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 144
# pop. radius: 1.1031853471159956
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 145
# pop. radius: 1.0924888001204403
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 146
# pop. radius: 1.0924888001204403
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 147
# pop. radius: 1.0924888001204403
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 148
# pop. radius: 1.0924888001204403
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 149
# pop. radius: 1.0924888001204403
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 150
# pop. radius: 1.0924888001204403
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 151
# pop. radius: 1.0924888001204403
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 152
# pop. radius: 1.0924888001204403
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 153
# pop. radius: 1.0924888001204403
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 154
# pop. radius: 1.0931937287579503
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 155
# pop. radius: 1.0931937287579503
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 156
# pop. radius: 1.0931937287579503
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 157
# pop. radius: 1.0931937287579503
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 158
# pop. radius: 1.0931937287579503
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 159
# pop. radius: 1.0931937287579503
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 160
# pop. radius: 1.0931937287579503
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 161
# pop. radius: 1.0931937287579503
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 162
# pop. radius: 1.0931937287579503
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 163
# pop. radius: 1.0931937287579503
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 164
# pop. radius: 1.0867260881888257
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 165
# pop. radius: 1.0867260881888257
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 166
# pop. radius: 1.0867260881888257
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 167
# pop. radius: 1.0897121082386287
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 168
# pop. radius: 1.0897121082386287
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 169
# pop. radius: 1.082018573932212
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 170
# pop. radius: 1.082018573932212
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 171
# pop. radius: 1.082018573932212
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 172
# pop. radius: 1.082018573932212
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 173
# pop. radius: 1.0808072765809489
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 174
# pop. radius: 1.0808072765809489
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 175
# pop. radius: 1.0808072765809489
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 176
# pop. radius: 1.080078870891632
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 177
# pop. radius: 1.080078870891632
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 178
# pop. radius: 1.0875927082131462
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 179
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 180
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 181
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 182
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 183
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 184
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 185
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 186
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 187
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 188
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 189
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 190
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 191
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 192
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 193
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 194
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 195
# pop. radius: 1.0747573522170812
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 196
# pop. radius: 1.0845284042114167
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 197
# pop. radius: 1.0845284042114167
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 198
# pop. radius: 1.0845284042114167
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 199
# pop. radius: 1.0845284042114167
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 200
# pop. radius: 1.077784481113634
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 201
# pop. radius: 1.077784481113634
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 202
# pop. radius: 1.077784481113634
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 203
# pop. radius: 1.077784481113634
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 204
# pop. radius: 1.077784481113634
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 205
# pop. radius: 1.077784481113634
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 206
# pop. radius: 1.0749525327037137
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 207
# pop. radius: 1.0749525327037137
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 208
# pop. radius: 1.0749525327037137
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 209
# pop. radius: 1.0749525327037137
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 210
# pop. radius: 1.0749525327037137
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 211
# pop. radius: 1.0749525327037137
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 212
# pop. radius: 1.0749525327037137
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 213
# pop. radius: 1.0749525327037137
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 214
# pop. radius: 1.0749525327037137
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 215
# pop. radius: 1.0739306927284715
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 216
# pop. radius: 1.0739306927284715
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 217
# pop. radius: 1.0702972395694583
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 218
# pop. radius: 1.0702972395694583
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 219
# pop. radius: 1.0702972395694583
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 220
# pop. radius: 1.0767961858908102
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 221
# pop. radius: 1.0767961858908102
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 222
# pop. radius: 1.0767961858908102
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 223
# pop. radius: 1.0767961858908102
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 224
# pop. radius: 1.0755538768674562
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 225
# pop. radius: 1.0755538768674562
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 226
# pop. radius: 1.053944959354537
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 227
# pop. radius: 1.053944959354537
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 228
# pop. radius: 1.055492691355016
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 229
# pop. radius: 1.055492691355016
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 230
# pop. radius: 1.055492691355016
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 231
# pop. radius: 1.0443265282567433
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 232
# pop. radius: 1.0443265282567433
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 233
# pop. radius: 1.0647580930143379
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 234
# pop. radius: 1.0647580930143379
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 235
# pop. radius: 1.0668583255123942
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 236
# pop. radius: 1.0668583255123942
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 237
# pop. radius: 1.0668583255123942
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 238
# pop. radius: 1.0668583255123942
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 239
# pop. radius: 1.0668583255123942
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 240
# pop. radius: 1.0668583255123942
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 241
# pop. radius: 1.0621681505886083
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 242
# pop. radius: 1.0621681505886083
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 243
# pop. radius: 1.062448027809203
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 244
# pop. radius: 1.062448027809203
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 245
# pop. radius: 1.0563633371156882
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 246
# pop. radius: 1.0557480764445042
# x_best = [ -6.62057286 -12.75542377  26.0085218  -18.66010671 -35.52970711], f_best = 0.9695590838455356
# 247
# pop. radius: 1.0903539182708333
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 248
# pop. radius: 1.0903539182708333
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 249
# pop. radius: 1.0903539182708333
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 250
# pop. radius: 1.0903539182708333
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 251
# pop. radius: 1.0905833839797534
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 252
# pop. radius: 1.0794767823221916
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 253
# pop. radius: 1.0794767823221916
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 254
# pop. radius: 1.0794767823221916
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 255
# pop. radius: 0.9678280695279287
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 256
# pop. radius: 0.9678280695279287
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 257
# pop. radius: 0.9678280695279287
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 258
# pop. radius: 0.9593279143207704
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 259
# pop. radius: 0.9593279143207704
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 260
# pop. radius: 0.9593279143207704
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 261
# pop. radius: 0.9599533879999033
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 262
# pop. radius: 0.9599533879999033
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 263
# pop. radius: 0.9573799010324747
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 264
# pop. radius: 0.9586181591735192
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 265
# pop. radius: 0.9586181591735192
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 266
# pop. radius: 0.9586181591735192
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 267
# pop. radius: 0.9586181591735192
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 268
# pop. radius: 0.958208049085654
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 269
# pop. radius: 0.958208049085654
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 270
# pop. radius: 0.958208049085654
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 271
# pop. radius: 0.958208049085654
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 272
# pop. radius: 0.958208049085654
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 273
# pop. radius: 0.9581254800060464
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 274
# pop. radius: 0.9581254800060464
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 275
# pop. radius: 0.9581254800060464
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 276
# pop. radius: 0.9603052564521866
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 277
# pop. radius: 0.9749345242243388
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 278
# pop. radius: 0.957548092837455
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 279
# pop. radius: 0.9577097369892839
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 280
# pop. radius: 0.9577097369892839
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 281
# pop. radius: 0.9486495665531531
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 282
# pop. radius: 0.9522308093222752
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 283
# pop. radius: 0.9522308093222752
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 284
# pop. radius: 0.9522308093222752
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 285
# pop. radius: 0.9776191707535034
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 286
# pop. radius: 0.9826323703975445
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 287
# pop. radius: 0.9866206313661634
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 288
# pop. radius: 0.9866206313661634
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 289
# pop. radius: 0.9868392522728181
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 290
# pop. radius: 0.9896649992141354
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 291
# pop. radius: 0.9896649992141354
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 292
# pop. radius: 0.9896649992141354
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 293
# pop. radius: 0.9845231932731502
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 294
# pop. radius: 0.9845231932731502
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 295
# pop. radius: 0.9845231932731502
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 296
# pop. radius: 0.9845231932731502
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 297
# pop. radius: 0.9843393891276379
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 298
# pop. radius: 0.9843393891276379
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 299
# pop. radius: 0.9843393891276379
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 300
# pop. radius: 0.9843393891276379
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 301
# pop. radius: 0.9967257250349514
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 302
# pop. radius: 0.9967257250349514
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 303
# pop. radius: 0.9967257250349514
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 304
# pop. radius: 0.974037711529442
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 305
# pop. radius: 0.9878569761760327
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 306
# pop. radius: 0.9878569761760327
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 307
# pop. radius: 0.9803948012620515
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 308
# pop. radius: 0.9803948012620515
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 309
# pop. radius: 0.9119162501218427
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 310
# pop. radius: 0.9131500688741893
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 311
# pop. radius: 0.9131500688741893
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 312
# pop. radius: 0.9131500688741893
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 313
# pop. radius: 0.9131500688741893
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 314
# pop. radius: 0.9185295788126593
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 315
# pop. radius: 0.9260273726751574
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 316
# pop. radius: 0.9264976082680833
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 317
# pop. radius: 0.7154047721641771
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 318
# pop. radius: 0.7154047721641771
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 319
# pop. radius: 0.6780072266224172
# x_best = [-12.29869138  -7.82467991   0.48790879  -5.37683319 -36.65486191], f_best = 0.9243449031005729
# 320
# pop. radius: 0.680364884769586
# x_best = [ -3.86712465 -12.54776766 -15.98556717  -6.0781598   14.70914131], f_best = 0.5756000355224083
# 321
# pop. radius: 0.6792516090384905
# x_best = [ -3.86712465 -12.54776766 -15.98556717  -6.0781598   14.70914131], f_best = 0.5756000355224083
# 322
# pop. radius: 0.6792516090384905
# x_best = [ -3.86712465 -12.54776766 -15.98556717  -6.0781598   14.70914131], f_best = 0.5756000355224083
# 323
# pop. radius: 0.6849817685901022
# x_best = [ -3.86712465 -12.54776766 -15.98556717  -6.0781598   14.70914131], f_best = 0.5756000355224083
# 324
# pop. radius: 0.6849817685901022
# x_best = [ -3.86712465 -12.54776766 -15.98556717  -6.0781598   14.70914131], f_best = 0.5756000355224083
# 325
# pop. radius: 0.6875323529585948
# x_best = [ -3.86712465 -12.54776766 -15.98556717  -6.0781598   14.70914131], f_best = 0.5756000355224083
# 326
# pop. radius: 0.6875323529585948
# x_best = [ -3.86712465 -12.54776766 -15.98556717  -6.0781598   14.70914131], f_best = 0.5756000355224083
# 327
# pop. radius: 0.690796612973723
# x_best = [ -3.86712465 -12.54776766 -15.98556717  -6.0781598   14.70914131], f_best = 0.5756000355224083
# 328
# pop. radius: 0.690796612973723
# x_best = [ -3.86712465 -12.54776766 -15.98556717  -6.0781598   14.70914131], f_best = 0.5756000355224083
# 329
# pop. radius: 0.6956401752134638
# x_best = [ -3.86712465 -12.54776766 -15.98556717  -6.0781598   14.70914131], f_best = 0.5756000355224083
# 330
# pop. radius: 0.6956401752134638
# ...
# 885
# pop. radius: 0.4618175371535016
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 886
# pop. radius: 0.4618175371535016
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 887
# pop. radius: 0.4618175371535016
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 888
# pop. radius: 0.4618175371535016
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 889
# pop. radius: 0.4618175371535016
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 890
# pop. radius: 0.455576621276664
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 891
# pop. radius: 0.455576621276664
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 892
# pop. radius: 0.455576621276664
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 893
# pop. radius: 0.455576621276664
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 894
# pop. radius: 0.455576621276664
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 895
# pop. radius: 0.455576621276664
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 896
# pop. radius: 0.455576621276664
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 897
# pop. radius: 0.4554057065056582
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 898
# pop. radius: 0.4554057065056582
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 899
# pop. radius: 0.4554057065056582
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 900
# pop. radius: 0.4594456776242729
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 901
# pop. radius: 0.4594456776242729
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 902
# pop. radius: 0.4594456776242729
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 903
# pop. radius: 0.4594456776242729
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 904
# pop. radius: 0.4594456776242729
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 905
# pop. radius: 0.4594456776242729
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 906
# pop. radius: 0.4594456776242729
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 907
# pop. radius: 0.4594456776242729
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 908
# pop. radius: 0.4594456776242729
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 909
# pop. radius: 0.4594456776242729
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 910
# pop. radius: 0.4594456776242729
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 911
# pop. radius: 0.4594456776242729
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 912
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 913
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 914
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 915
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 916
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 917
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 918
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 919
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 920
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 921
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 922
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 923
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 924
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 925
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 926
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 927
# pop. radius: 0.541622810566731
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 928
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 929
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 930
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 931
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 932
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 933
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 934
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 935
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 936
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 937
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 938
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 939
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 940
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 941
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 942
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 943
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 944
# pop. radius: 0.538143204592081
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 945
# pop. radius: 0.5358633957190215
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 946
# pop. radius: 0.5358633957190215
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 947
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 948
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 949
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 950
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 951
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 952
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 953
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 954
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 955
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 956
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 957
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 958
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 959
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 960
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 961
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 962
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 963
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 964
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 965
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 966
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 967
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 968
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 969
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 970
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 971
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 972
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 973
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 974
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 975
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 976
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 977
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 978
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 979
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 980
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 981
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 982
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 983
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 984
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 985
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 986
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 987
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 988
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 989
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 990
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 991
# pop. radius: 0.5359290178433185
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 992
# pop. radius: 0.5412785158509471
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 993
# pop. radius: 0.5412785158509471
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 994
# pop. radius: 0.5412785158509471
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 995
# pop. radius: 0.5412785158509471
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 996
# pop. radius: 0.5412785158509471
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 997
# pop. radius: 0.5412785158509471
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 998
# pop. radius: 0.5412785158509471
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 999
# pop. radius: 0.5412785158509471
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# 1000
# pop. radius: 0.5412785158509471
# x_best = [ 8.86479109  4.72122056 -5.21321422 -0.31032157 -7.05041492], f_best = 0.23070783326018363
# x_best = [ 0.08864791  0.04721221 -0.05213214 -0.00310322 -0.07050415], f_best = 0.23070783326018363

# %%
hist_values = met.historical
tl.printmsk(hist_values)
# Out:
# |-- {dict: 4}
# |  |-- fitness = {list: 2001}
# |  |  |-- 0 = {ndarray: }
# :  :  :
# |  |-- position = {list: 2001}
# |  |  |-- 0 = {ndarray: 5}
# :  :  :
# |  |-- centroid = {list: 2001}
# |  |  |-- 0 = {ndarray: 5}
# :  :  :
# |  |-- radius = {list: 2001}
# |  |  |-- 0 = {float64}
# :  :  :

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].plot(hist_values['fitness'], lw=2)
axs[0].set_xlabel('Iteration'), axs[0].set_ylabel('Fitness')

axs[1].plot(hist_values['position'])
# axs[1].plot(hist_values['radius'])
axs[1].set_xlabel(r'Iteration'), axs[1].set_ylabel(r'Position')
axs[1].legend([f"$x_{ii+1}$" for ii in range(6)], frameon=False)

plt.show()

# %% [markdown]
# ### 5.1 Using CEC2005 functions
# To use them we need to install the package `optproblems`

# %%
#!pip install optproblems

# %%
from customhys import benchmark_func as bf

# %%
problem = bf.CEC2005("F4", 5)

# %%
met = mh.Metaheuristic(problem.get_formatted_problem(), heur, num_iterations=1000)
met.verbose = True
met.run()
print('x_best = {}, f_best = {}'.format(*met.get_solution()))
# Out:
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 1000, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 2) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 2
# Operador 0: ('differential_mutation', {'expression': 'current-to-best', 'num_rands': 2, 'factor': 1.0}, 'greedy')
# Operador 1: ('differential_crossover', {'crossover_rate': 0.2, 'version': 'binomial'}, 'greedy')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 5 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
#
# Search operators to employ:
# differential_mutation(expression='current-to-best',num_rands=2,factor=1.0) with greedy
# differential_crossover(crossover_rate=0.2,version='binomial') with greedy
# --------------------------------------------------
# 1
# pop. radius: 1.7601051420128158
# x_best = [ 24.90534324 -93.27491853  -2.93668058 -45.97777553 -38.65633599], f_best = 12194.615315496409
# 2
# pop. radius: 1.8022601358897743
# x_best = [  52.73088942  -20.30404415 -100.          -77.6872364    62.62760946], f_best = 10335.821567746412
# 3
# pop. radius: 1.9977073183565275
# x_best = [ 16.94791231 -33.06028603 -96.25189376 -23.96673402 100.        ], f_best = 5509.61803034082
# 4
# pop. radius: 1.9947678725082045
# x_best = [ 16.94791231 -33.06028603 -96.25189376 -23.96673402 100.        ], f_best = 5509.61803034082
# 5
# pop. radius: 2.003158711086631
# x_best = [ 16.94791231 -33.06028603 -96.25189376 -23.96673402 100.        ], f_best = 5509.61803034082
# 6
# pop. radius: 2.1318519593308216
# x_best = [  24.90534324 -100.           -2.93668058  -56.51738875   96.98894366], f_best = 2027.3623715737276
# 7
# pop. radius: 2.1515657524013396
# x_best = [  24.90534324 -100.           -2.93668058  -56.51738875   96.98894366], f_best = 1465.1362233672373
# 8
# pop. radius: 2.127271032506979
# x_best = [  24.90534324 -100.           -2.93668058  -56.51738875   96.98894366], f_best = 1416.3216943480654
# 9
# pop. radius: 2.163017668668118
# x_best = [  24.90534324 -100.           -2.93668058  -56.51738875   96.98894366], f_best = 1416.3216943480654
# 10
# pop. radius: 2.1647656688353076
# x_best = [  24.90534324 -100.           -2.93668058  -56.51738875   96.98894366], f_best = 1416.3216943480654
# 11
# pop. radius: 2.1670690374792514
# x_best = [  24.90534324 -100.           -2.93668058  -56.51738875   96.98894366], f_best = 1416.3216943480654
# 12
# pop. radius: 2.1517518440078383
# x_best = [  24.90534324 -100.           -2.93668058  -56.51738875   96.98894366], f_best = 1416.3216943480654
# 13
# pop. radius: 2.1598572021801865
# x_best = [  24.90534324 -100.           -2.93668058  -56.51738875   96.98894366], f_best = 1416.3216943480654
# 14
# pop. radius: 2.1674005816722306
# x_best = [  24.90534324 -100.           -2.93668058  -56.51738875   96.98894366], f_best = 1416.3216943480654
# 15
# pop. radius: 2.2122832645212567
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 16
# pop. radius: 2.256081466968942
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 17
# pop. radius: 2.2973106254237745
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 18
# pop. radius: 2.2973106254237745
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 19
# pop. radius: 2.2973106254237745
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 20
# pop. radius: 2.1755622047372793
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 21
# pop. radius: 2.179642848787437
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 22
# pop. radius: 2.223089834772143
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 23
# pop. radius: 2.2284098804435093
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 24
# pop. radius: 2.2284098804435093
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 25
# pop. radius: 2.229004177262143
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 26
# pop. radius: 2.2291912027368115
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 27
# pop. radius: 1.9477078645937105
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 28
# pop. radius: 1.9730682781942495
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 29
# pop. radius: 1.9730682781942495
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 30
# pop. radius: 1.9730682781942495
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 31
# pop. radius: 1.9781577202856246
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 32
# pop. radius: 1.9951799566786845
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 33
# pop. radius: 1.9951799566786845
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 34
# pop. radius: 1.9951799566786845
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 720.860668623736
# 35
# pop. radius: 1.9951799566786845
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 678.1777886008972
# 36
# pop. radius: 1.9881714926517582
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 666.3089468491228
# 37
# pop. radius: 1.9881714926517582
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 666.3089468491228
# 38
# pop. radius: 1.9881714926517582
# x_best = [  39.61019314 -100.          -25.1575717   -64.24242296  100.        ], f_best = 666.3089468491228
# 39
# pop. radius: 1.9888793002063858
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 40
# pop. radius: 1.9976133046905835
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 41
# pop. radius: 1.9976133046905835
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 42
# pop. radius: 2.005510362275507
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 43
# pop. radius: 2.005510362275507
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 44
# pop. radius: 2.005510362275507
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 45
# pop. radius: 2.005510362275507
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 46
# pop. radius: 2.005510362275507
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 47
# pop. radius: 2.010875793431924
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 48
# pop. radius: 2.0021811713493443
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 49
# pop. radius: 2.0021811713493443
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 50
# pop. radius: 2.017113589581298
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 51
# pop. radius: 2.017113589581298
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 52
# pop. radius: 2.014178168648226
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 53
# pop. radius: 2.014178168648226
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 54
# pop. radius: 2.0356000490943855
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 55
# pop. radius: 2.0356000490943855
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 56
# pop. radius: 2.0502074448879166
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 57
# pop. radius: 2.0502074448879166
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 58
# pop. radius: 2.0502074448879166
# x_best = [  28.55966911  -82.68518834  -10.4682225  -100.          100.        ], f_best = 270.0528773250653
# 59
# pop. radius: 2.0435060733681447
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 60
# pop. radius: 2.0435060733681447
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 61
# pop. radius: 2.0435060733681447
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 62
# pop. radius: 2.0435060733681447
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 63
# pop. radius: 2.0533534752007085
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 64
# pop. radius: 2.0533534752007085
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 65
# pop. radius: 2.0695971083919518
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 66
# pop. radius: 2.0695971083919518
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 67
# pop. radius: 2.0695971083919518
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 68
# pop. radius: 2.0695971083919518
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 69
# pop. radius: 2.0695971083919518
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 70
# pop. radius: 2.074762544280276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 71
# pop. radius: 2.074762544280276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 72
# pop. radius: 2.074762544280276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 73
# pop. radius: 2.113742567752577
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 74
# pop. radius: 2.1235470074343046
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 75
# pop. radius: 2.1235470074343046
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 76
# pop. radius: 2.1235470074343046
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 77
# pop. radius: 2.1235470074343046
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 78
# pop. radius: 2.1235470074343046
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 79
# pop. radius: 2.1235470074343046
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 80
# pop. radius: 2.1235470074343046
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 81
# pop. radius: 2.1281818582524443
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 82
# pop. radius: 2.1281818582524443
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 83
# pop. radius: 2.1281818582524443
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 84
# pop. radius: 2.1281818582524443
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 85
# pop. radius: 2.117279607828666
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 86
# pop. radius: 2.1109611961221266
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 87
# pop. radius: 2.1109611961221266
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 88
# pop. radius: 2.1085590455480276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 89
# pop. radius: 2.1085590455480276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 90
# pop. radius: 2.1085590455480276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 91
# pop. radius: 2.1085590455480276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 92
# pop. radius: 2.1085590455480276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 93
# pop. radius: 2.1085590455480276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 94
# pop. radius: 2.1085590455480276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 95
# pop. radius: 2.1085590455480276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 96
# pop. radius: 2.1085590455480276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 97
# pop. radius: 2.1085590455480276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 98
# pop. radius: 2.1085590455480276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 99
# pop. radius: 2.1085590455480276
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 100
# pop. radius: 2.1053800100790174
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 101
# pop. radius: 2.1053800100790174
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 102
# pop. radius: 2.108347383346972
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 103
# pop. radius: 2.085832538049159
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 104
# pop. radius: 2.085832538049159
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 105
# pop. radius: 2.085832538049159
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 106
# pop. radius: 2.085832538049159
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 107
# pop. radius: 2.080912492372105
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 108
# pop. radius: 2.0749646135056006
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 109
# pop. radius: 2.1008885148209973
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 110
# pop. radius: 2.1323926162954163
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 111
# pop. radius: 2.1323926162954163
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 112
# pop. radius: 2.1323926162954163
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 113
# pop. radius: 2.1323926162954163
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 114
# pop. radius: 2.136169272261257
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 115
# pop. radius: 2.136169272261257
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 116
# pop. radius: 2.136169272261257
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 117
# pop. radius: 2.136169272261257
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 118
# pop. radius: 2.1506815530313905
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 119
# pop. radius: 2.1506815530313905
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 120
# pop. radius: 2.1476718762758513
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 121
# pop. radius: 2.1476718762758513
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 122
# pop. radius: 2.1476718762758513
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 123
# pop. radius: 2.1476718762758513
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 124
# pop. radius: 2.1476718762758513
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 125
# pop. radius: 2.1512248744583977
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 126
# pop. radius: 2.1512248744583977
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 127
# pop. radius: 2.1512248744583977
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 128
# pop. radius: 2.1545217918759767
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 129
# pop. radius: 2.1592697424996006
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 130
# pop. radius: 2.1592697424996006
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 131
# pop. radius: 2.1592697424996006
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 132
# pop. radius: 2.1665910941836493
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 133
# pop. radius: 2.1665910941836493
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 134
# pop. radius: 2.1791738330575665
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 135
# pop. radius: 2.1791738330575665
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 136
# pop. radius: 2.1791738330575665
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 137
# pop. radius: 2.1791738330575665
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 138
# pop. radius: 2.1791738330575665
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 139
# pop. radius: 2.1791738330575665
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 140
# pop. radius: 2.1791738330575665
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 141
# pop. radius: 2.1791738330575665
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 142
# pop. radius: 2.170537222812451
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 143
# pop. radius: 2.170537222812451
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 144
# pop. radius: 2.170537222812451
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 145
# pop. radius: 2.170537222812451
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 146
# pop. radius: 2.170537222812451
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 147
# pop. radius: 2.1683612439415785
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 148
# pop. radius: 2.173997139790344
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 149
# pop. radius: 2.173997139790344
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 150
# pop. radius: 2.173997139790344
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 151
# pop. radius: 2.173997139790344
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 152
# pop. radius: 2.173997139790344
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 153
# pop. radius: 2.173997139790344
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 154
# pop. radius: 2.173997139790344
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 155
# pop. radius: 2.173997139790344
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 156
# pop. radius: 2.173997139790344
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 157
# pop. radius: 2.173997139790344
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 158
# pop. radius: 2.173997139790344
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 159
# pop. radius: 2.1540960952216452
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 160
# pop. radius: 2.1540960952216452
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 161
# pop. radius: 2.2139357885823254
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 162
# pop. radius: 2.2139357885823254
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 163
# pop. radius: 2.2170713513515836
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 164
# pop. radius: 2.2170713513515836
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 165
# pop. radius: 2.2170713513515836
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 166
# pop. radius: 2.2167424495584296
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 167
# pop. radius: 2.2167424495584296
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 168
# pop. radius: 2.2167424495584296
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 169
# pop. radius: 2.2167424495584296
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 170
# pop. radius: 2.220720223551811
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 171
# pop. radius: 2.20656558405085
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 172
# pop. radius: 2.20656558405085
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 173
# pop. radius: 2.20656558405085
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 174
# pop. radius: 2.20656558405085
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 175
# pop. radius: 2.2030629962633097
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 176
# pop. radius: 2.081477070362708
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 177
# pop. radius: 2.081477070362708
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 178
# pop. radius: 2.081477070362708
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 179
# pop. radius: 2.081477070362708
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 180
# pop. radius: 2.081477070362708
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 181
# pop. radius: 2.077386054833636
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 182
# pop. radius: 2.077386054833636
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 183
# pop. radius: 2.077386054833636
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 184
# pop. radius: 2.077386054833636
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 185
# pop. radius: 2.077386054833636
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 186
# pop. radius: 2.077386054833636
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 187
# pop. radius: 2.077386054833636
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 188
# pop. radius: 2.077386054833636
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 189
# pop. radius: 2.077386054833636
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 190
# pop. radius: 2.0566115536689433
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 191
# pop. radius: 2.0566115536689433
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 192
# pop. radius: 2.0566115536689433
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 193
# pop. radius: 2.0566115536689433
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 194
# pop. radius: 2.0474680848984246
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 195
# pop. radius: 2.0406731714070823
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 196
# pop. radius: 2.0329004871267835
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 197
# pop. radius: 2.0329004871267835
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 198
# pop. radius: 2.0329004871267835
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 199
# pop. radius: 2.0329004871267835
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 200
# pop. radius: 2.0329004871267835
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 201
# pop. radius: 2.0329004871267835
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 202
# pop. radius: 1.9871601364010403
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 203
# pop. radius: 1.987752663423593
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 204
# pop. radius: 1.987752663423593
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 205
# pop. radius: 1.987752663423593
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 206
# pop. radius: 1.987752663423593
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 207
# pop. radius: 1.987752663423593
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 208
# pop. radius: 1.987752663423593
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 209
# pop. radius: 1.9850716397167694
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 210
# pop. radius: 1.9860281010404968
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 211
# pop. radius: 1.9860281010404968
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 212
# pop. radius: 1.98401435328531
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 213
# pop. radius: 1.98401435328531
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 214
# pop. radius: 1.98401435328531
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 215
# pop. radius: 2.0046380732578197
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 216
# pop. radius: 2.0046380732578197
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 217
# pop. radius: 2.0046380732578197
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 218
# pop. radius: 2.0046380732578197
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 219
# pop. radius: 2.0046380732578197
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 220
# pop. radius: 2.024680736676334
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 221
# pop. radius: 2.024680736676334
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 222
# pop. radius: 2.024680736676334
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 223
# pop. radius: 2.024680736676334
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 224
# pop. radius: 2.024680736676334
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 225
# pop. radius: 2.024680736676334
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 226
# pop. radius: 2.02338161978236
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 227
# pop. radius: 2.02338161978236
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 228
# pop. radius: 2.02338161978236
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 229
# pop. radius: 2.02338161978236
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 230
# pop. radius: 2.02338161978236
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 231
# pop. radius: 2.018864025336381
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 232
# pop. radius: 2.018864025336381
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 233
# pop. radius: 2.018864025336381
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 234
# pop. radius: 2.018864025336381
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 235
# pop. radius: 2.018864025336381
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 236
# pop. radius: 2.0180249666236456
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 237
# pop. radius: 2.0180249666236456
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 238
# pop. radius: 2.02756340742692
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 239
# pop. radius: 2.02756340742692
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 240
# pop. radius: 2.02756340742692
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 241
# pop. radius: 2.02756340742692
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 242
# pop. radius: 2.02756340742692
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 243
# pop. radius: 2.02756340742692
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 244
# pop. radius: 2.02756340742692
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 245
# pop. radius: 2.02756340742692
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 246
# pop. radius: 2.02756340742692
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 247
# pop. radius: 2.02756340742692
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 248
# pop. radius: 2.0238572217040347
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 249
# pop. radius: 2.0238572217040347
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 250
# pop. radius: 2.0238572217040347
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 251
# pop. radius: 2.0238572217040347
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 252
# pop. radius: 2.0238572217040347
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 253
# pop. radius: 2.0238572217040347
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 254
# pop. radius: 2.0238572217040347
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 255
# pop. radius: 2.0238572217040347
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 256
# pop. radius: 2.0279265931118333
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 257
# pop. radius: 2.0279265931118333
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 258
# pop. radius: 2.0279265931118333
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 259
# pop. radius: 2.0279265931118333
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 260
# pop. radius: 2.0279265931118333
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 261
# pop. radius: 2.0279265931118333
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 262
# pop. radius: 2.0279265931118333
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 263
# pop. radius: 2.0279265931118333
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 264
# pop. radius: 2.0279265931118333
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 265
# pop. radius: 2.0354490333656594
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 266
# pop. radius: 2.0354490333656594
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 267
# pop. radius: 2.0354490333656594
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 268
# pop. radius: 2.032168040048253
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 269
# pop. radius: 2.032168040048253
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 270
# pop. radius: 2.032168040048253
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 271
# pop. radius: 2.0322735257915707
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 272
# pop. radius: 2.0322735257915707
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 273
# pop. radius: 2.0322735257915707
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 274
# pop. radius: 2.0322735257915707
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 275
# pop. radius: 2.0325081271484593
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 276
# pop. radius: 2.0325081271484593
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 277
# pop. radius: 2.0325081271484593
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 278
# pop. radius: 2.061254476969026
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 279
# pop. radius: 2.061254476969026
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 280
# pop. radius: 2.061254476969026
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 281
# pop. radius: 2.061254476969026
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 282
# pop. radius: 2.061254476969026
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 283
# pop. radius: 2.061254476969026
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 284
# pop. radius: 2.061254476969026
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 285
# pop. radius: 2.061254476969026
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 286
# pop. radius: 2.061254476969026
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 287
# pop. radius: 2.0580382930566805
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 288
# pop. radius: 2.0580382930566805
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 289
# pop. radius: 2.0580382930566805
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 290
# pop. radius: 2.0624087896849503
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 291
# pop. radius: 2.0624087896849503
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 292
# pop. radius: 2.0624087896849503
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 293
# pop. radius: 2.0624087896849503
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 294
# pop. radius: 2.0624087896849503
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 295
# pop. radius: 2.0624087896849503
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 296
# pop. radius: 2.0880842366870254
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 297
# pop. radius: 2.0880842366870254
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 298
# pop. radius: 2.0880842366870254
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 299
# pop. radius: 2.0836380508537755
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 300
# pop. radius: 2.0836380508537755
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 301
# pop. radius: 2.0836380508537755
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 302
# pop. radius: 2.088367825828584
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 303
# pop. radius: 2.088367825828584
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 304
# pop. radius: 2.088367825828584
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 305
# pop. radius: 2.088367825828584
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 306
# pop. radius: 2.088367825828584
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 307
# pop. radius: 2.088367825828584
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 308
# pop. radius: 2.088696736554227
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 309
# pop. radius: 2.088696736554227
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 310
# pop. radius: 2.088696736554227
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 311
# pop. radius: 2.088696736554227
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 312
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 313
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 314
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 315
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 316
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 317
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 318
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 319
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 320
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 321
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 322
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 323
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 324
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 325
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 326
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 327
# pop. radius: 2.0795161975509724
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 328
# pop. radius: 2.0909592195709337
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 329
# pop. radius: 2.0980673384588435
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 330
# pop. radius: 2.0980673384588435
# x_best = [ 30.58296404 -80.92101706  -9.2281203  -83.89792988  77.9930563 ], f_best = -320.7293333247196
# 331
# pop. radius: 2.0980673384588435
# ...
# 890
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 891
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 892
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 893
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 894
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 895
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 896
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 897
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 898
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 899
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 900
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 901
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 902
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 903
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 904
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 905
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 906
# pop. radius: 0.45787946816792596
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 907
# pop. radius: 0.45942104202231376
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 908
# pop. radius: 0.457999257717775
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 909
# pop. radius: 0.4510718388750966
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 910
# pop. radius: 0.4510718388750966
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 911
# pop. radius: 0.4510718388750966
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 912
# pop. radius: 0.4510718388750966
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 913
# pop. radius: 0.4510718388750966
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 914
# pop. radius: 0.4510718388750966
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 915
# pop. radius: 0.4510718388750966
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 916
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 917
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 918
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 919
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 920
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 921
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 922
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 923
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 924
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 925
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 926
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 927
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 928
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 929
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 930
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 931
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 932
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 933
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 934
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 935
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 936
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 937
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 938
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 939
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 940
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 941
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 942
# pop. radius: 0.3966461556996386
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 943
# pop. radius: 0.39302034047980056
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 944
# pop. radius: 0.39302034047980056
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 945
# pop. radius: 0.39302034047980056
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 946
# pop. radius: 0.39302034047980056
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 947
# pop. radius: 0.39302034047980056
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 948
# pop. radius: 0.3969881621201452
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 949
# pop. radius: 0.3969881621201452
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 950
# pop. radius: 0.3017780637459815
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 951
# pop. radius: 0.3017780637459815
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 952
# pop. radius: 0.3017780637459815
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 953
# pop. radius: 0.3049660817977797
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 954
# pop. radius: 0.31014386830840057
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 955
# pop. radius: 0.31014386830840057
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 956
# pop. radius: 0.31014386830840057
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 957
# pop. radius: 0.31014386830840057
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 958
# pop. radius: 0.31014386830840057
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 959
# pop. radius: 0.31014386830840057
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 960
# pop. radius: 0.31014386830840057
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 961
# pop. radius: 0.3123811811393331
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 962
# pop. radius: 0.3123811811393331
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 963
# pop. radius: 0.3123811811393331
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 964
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 965
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 966
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 967
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 968
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 969
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 970
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 971
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 972
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 973
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 974
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 975
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 976
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 977
# pop. radius: 0.3130574604252703
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 978
# pop. radius: 0.31147472187538044
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 979
# pop. radius: 0.31147472187538044
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 980
# pop. radius: 0.31147472187538044
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 981
# pop. radius: 0.31147472187538044
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 982
# pop. radius: 0.31147472187538044
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 983
# pop. radius: 0.31147472187538044
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 984
# pop. radius: 0.31147472187538044
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 985
# pop. radius: 0.31147472187538044
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 986
# pop. radius: 0.31147472187538044
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 987
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 988
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 989
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 990
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 991
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 992
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 993
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 994
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 995
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 996
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 997
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 998
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 999
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# 1000
# pop. radius: 0.3042337985634032
# x_best = [ 35.20451523 -83.78254601 -11.15209246 -78.20322334  79.67655623], f_best = -416.42628379904204
# x_best = [ 0.35204515 -0.83782546 -0.11152092 -0.78203223  0.79676556], f_best = -416.42628379904204

# %%
hist_values = met.historical
fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].plot(hist_values['fitness'], lw=2)
axs[0].set_xlabel('Iteration'), axs[0].set_ylabel('Fitness')

axs[1].plot(hist_values['position'])
# axs[1].plot(hist_values['radius'])
axs[1].set_xlabel(r'Iteration'), axs[1].set_ylabel(r'Position')
axs[1].legend([f"$x_{ii+1}$" for ii in range(6)], frameon=False)

plt.show()

# %%
dime = 20
fun = bf.CEC2005("F4", dime)

cate = fun.get_features()
prob = fun.get_formatted_problem()

hyp = hh.Hyperheuristic(heuristic_space="default.txt",
                        problem=prob, parameters=parameters, file_label='CEC-F4-20D-Exp2')

best_sol, best_perf, hist_curr, hist_best = hyp.solve()
# Out:
# --- LOG: Iniciando _solve_static ---
# --- LOG: Gerando solução inicial ---
# --- LOG: Entrando em _obtain_candidate_solution ---
# Parâmetro recebido sol: None
# Parâmetro action: None
# Parâmetro operators_weights: None
# Parâmetro top: None
# --- LOG: Criando solução inicial ---
# --- LOG: encoded_neighbour gerado: [80] ---
# --- LOG: Solução inicial gerada: [80] ---
# --- LOG: Avaliando solução inicial ---
# --- LOG: Iniciando evaluate_candidate_solution ---
# --- LOG: encoded_sequence recebido ---
# Tipo: <class 'list'> | Conteúdo: [80]
# --- LOG: encoded_sequence convertido para operadores ---
# [('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')]
# --- LOG: search_operators validado ---
# [('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')]
# --- LOG: Iniciando execuções da Metaheuristic ---
# --- LOG: Rodada 1/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 2/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 3/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 4/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 5/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 6/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 7/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 8/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 9/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 10/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 11/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 12/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 13/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 14/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 15/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 16/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 17/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 18/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 19/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 20/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 21/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 22/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 23/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 24/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 25/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 26/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 27/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 28/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 29/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Rodada 30/30 ---
# --- LOG: Iniciando Metaheuristic ---
# --- LOG: Parâmetros recebidos ---
# Num_agents: 30, Num_iterations: 100, Initial_scheme: random
# Verbose: False
# --- LOG: Criando população ---
# --- LOG: Verificando search_operators (total: 1) ---
# --- LOG: Estrutura de search_operators ---
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: Verificando simple_heuristics ---
# Total de operadores recebidos: 1
# Operador 0: ('genetic_crossover', {'pairing': 'cost', 'crossover': 'uniform', 'mating_pool_factor': 0.4}, 'probabilistic')
# --- LOG: process_operators finalizado com sucesso ---
# --- LOG: process_operators executado com sucesso ---
# --- LOG: Número máximo de iterações definido ---
# --- LOG: Número de dimensões: 20 ---
# --- LOG: Número de agentes: 30 ---
# --- LOG: Variáveis históricas inicializadas ---
# --- LOG: Verbose setado como: False ---
# --- LOG: Initial_scheme setado como: random ---
# --- LOG: Metaheuristic inicializada com sucesso ---
# --- LOG: Metaheuristic criada com sucesso ---
# --- LOG: Metaheuristic executada ---
# --- LOG: Avaliação finalizada ---
# --- LOG: fitness_stats ---
# {'nob': 30, 'Min': 26020.436852890944, 'Max': 82095.5936954938, 'Avg': 52277.02306284781, 'Std': 15105.816545422562, 'Skw': 0.20619416373350277, 'Kur': -0.8902231142691348, 'IQR': 21085.304956241423, 'Med': 49088.761733353895, 'MAD': 9702.797730882889}
# --- LOG: Performance inicial: 70174.06668959532 ---
# CEC-F4-20D-Exp2 :: Step:    0, Temp: 1.00e+02, Perf: 7.02e+04 [Initial]
# --- LOG: Passo 1 - Gerando vizinho ---
# --- LOG: Entrando em _obtain_candidate_solution ---
# Parâmetro recebido sol: [80]
# Parâmetro action: Restart
# Parâmetro operators_weights: None
# Parâmetro top: None
# --- LOG: sol é uma lista ou ndarray, aplicando perturbação ---
# --- LOG: Ação escolhida: Restart ---
# *** ERRO: Ação inválida ou não implementada: Restart ***
# --- LOG: Vizinho gerado: None ---
# --- LOG: Avaliando candidato ---
# --- LOG: Iniciando evaluate_candidate_solution ---
# --- LOG: encoded_sequence recebido ---
# Tipo: <class 'NoneType'> | Conteúdo: None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 10
#       5 prob = fun.get_formatted_problem()
#       7 hyp = hh.Hyperheuristic(heuristic_space="default.txt",
#       8                         problem=prob, parameters=parameters, file_label='CEC-F4-20D-Exp2')
# ---> 10 best_sol, best_perf, hist_curr, hist_best = hyp.solve()
#
# File d:\Documentos\Projetos\Ufersa\customhys\customhys\hyperheuristic.py:368, in Hyperheuristic.solve(self, mode, save_steps)
#     366     return self._solve_neural_network(save_steps)
#     367 else:  # default: 'static'
# --> 368     return self._solve_static(save_steps)
#
# File d:\Documentos\Projetos\Ufersa\customhys\customhys\hyperheuristic.py:430, in Hyperheuristic._solve_static(self, save_steps)
#     428 if isinstance(candidate_solution, np.ndarray):
#     429     candidate_solution = candidate_solution.tolist()
# --> 430 candidate_performance, candidate_details = self.evaluate_candidate_solution(candidate_solution)
#     431 print(f"--- LOG: Performance do candidato: {candidate_performance} ---")
#     433 if self.parameters['verbose']:
#
# File d:\Documentos\Projetos\Ufersa\customhys\customhys\hyperheuristic.py:814, in Hyperheuristic.evaluate_candidate_solution(self, encoded_sequence)
#     812 # Decode the sequence corresponding to the hyper/meta-heuristic
#     813 search_operators = encoded_sequence
# --> 814 if isinstance(encoded_sequence[0], int) or isinstance(encoded_sequence[0], np.int64):
#     815     search_operators = self.get_operators(encoded_sequence)
#     816     print(f"--- LOG: encoded_sequence convertido para operadores ---\n{search_operators}")
#
# TypeError: 'NoneType' object is not subscriptable

# %%
full_data = tl.merge_json("./data_files/raw/CEC-F4-20D-Exp2")
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 12.83it/s]
# Merged file saved: ./data_files/raw/CEC-F4-20D-Exp2.json

# %%
full_data = tl.read_json("./data_files/raw/CEC-F4-20D-Exp2.json")

# %%
num_steps = len(full_data)
# print(full_data['details'])
# historical_fitness = [[x[['fitness']][-1] for x in historical] for historical in full_data['details']]
historical_fitness = [x['details']['fitness'] for x in full_data]
performances = [x['performance'] for x in full_data]
steps = [x['step'] for x in full_data]

vis.show_performance_overview(steps, historical_fitness, performances)

# %%
initial_fitness = max([max([x['fitness'][0] for x in fitness_rep['details']['historical']]) for fitness_rep in full_data])
best_fitness = np.min(historical_fitness)

for ii, step in enumerate(steps):
    historical_data = full_data[ii]['details']['historical']
    all_fitness_repetitions = np.array([fitness_rep['fitness'] for fitness_rep in historical_data]).T

    fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12, 4), sharey='row', gridspec_kw={'width_ratios': [0.8, 0.2]})
    axs[0].plot(all_fitness_repetitions, 'g', alpha=0.75)
    axs[0].set_ylabel(r'Fitness')
    axs[0].set_xlabel(r'Iteration')
    axs[0].set_ylim([best_fitness, initial_fitness])

    axs[1].boxplot(historical_fitness[ii])
    axs[1].set_xlabel(r'Data')

    plt.suptitle(r'MH$^{' + '{}'.format(len(full_data[ii]['encoded_solution'])) + '} = \\{' +
              '}, '.join(['h_{' + str(x) for x in full_data[ii]['encoded_solution']]) + '}\\}$')
    plt.tight_layout()
    plt.show()
    # plt.savefig('hh_raw_fitness_s{}.eps'.format(data['step'][ii]))
